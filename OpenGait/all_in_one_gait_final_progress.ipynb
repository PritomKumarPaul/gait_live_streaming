# %%
# !git clone https://github.com/jdyjjj/All-in-One-Gait.git
# %cd All-in-One-Gait
# Out:
# Cloning into 'All-in-One-Gait'...
# remote: Enumerating objects: 2978, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 2978 (delta 11), reused 4 (delta 4), pack-reused 2959 (from 3)
# Receiving objects: 100% (2978/2978), 694.20 MiB | 17.05 MiB/s, done.
# Resolving deltas: 100% (363/363), done.
# Updating files: 100% (1428/1428), done.
# /content/All-in-One-Gait

# %%
# !pwd
# Out:
# /content/All-in-One-Gait

# %%
# !pip install cython-bbox==0.1.3 filterpy lap loguru motmetrics ninja
# Out:
# Collecting cython-bbox==0.1.3
#   Downloading cython_bbox-0.1.3.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lap
#   Downloading lap-0.5.13-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.6 kB)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting motmetrics
#   Downloading motmetrics-1.4.0-py3-none-any.whl.metadata (20 kB)
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from filterpy) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from filterpy) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from filterpy) (3.10.0)
# Requirement already satisfied: pandas>=0.23.1 in /usr/local/lib/python3.12/dist-packages (from motmetrics) (2.2.2)
# Collecting xmltodict>=0.12.0 (from motmetrics)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.1->motmetrics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.1->motmetrics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.1->motmetrics) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.1->motmetrics) (1.17.0)
# Downloading lap-0.5.13-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.8 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.9 MB/s eta 0:00:00
# Downloading motmetrics-1.4.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 13.3 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.0 MB/s eta 0:00:00
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Building wheels for collected packages: cython-bbox, filterpy
#   Building wheel for cython-bbox (setup.py) ... done
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp312-cp312-linux_x86_64.whl size=110501 sha256=03b610177e7ff6aea4bc48f53a70bad46e3c77ab9b506a8ed4b5e83fe6df93d4
#   Stored in directory: /root/.cache/pip/wheels/14/c4/74/4e07ea722663c406fc64b2e7f8b424fa08635746b67455c2ed
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=505eaf742a9a4ac0381aba4ca0fbbe3b24581d6707cc69c658b20cdb44a72806
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built cython-bbox filterpy
# Installing collected packages: cython-bbox, xmltodict, ninja, loguru, lap, motmetrics, filterpy
# Successfully installed cython-bbox-0.1.3 filterpy-1.4.5 lap-0.5.13 loguru-0.7.3 motmetrics-1.4.0 ninja-1.13.0 xmltodict-1.0.4

# %%
# !pip install onnxsim
# Out:
# Collecting onnxsim
#   Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting onnx (from onnxsim)
#   Downloading onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim) (13.9.4)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxsim) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxsim) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxsim) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxsim) (0.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim) (0.1.2)
# Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 68.7 MB/s eta 0:00:00
# Downloading onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 95.6 MB/s eta 0:00:00
# Installing collected packages: onnx, onnxsim
# Successfully installed onnx-1.20.1 onnxsim-0.6.2

# %%
# !pip install yolox --no-deps
# Out:
# Collecting yolox
#   Downloading yolox-0.3.0.tar.gz (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: yolox
#   Building wheel for yolox (setup.py) ... done
#   Created wheel for yolox: filename=yolox-0.3.0-cp312-cp312-linux_x86_64.whl size=1751513 sha256=1ed3e7453b430b6bfb6f3230873f08854cc4e0171f7d39c5745eb8ec192dd7d3
#   Stored in directory: /root/.cache/pip/wheels/d9/45/a2/d986df74b0b4ca0b790cd855d023a7c49d6512d4db2d243175
# Successfully built yolox
# Installing collected packages: yolox
# Successfully installed yolox-0.3.0

# %%
# !pip install thop pycocotools tabulate
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (2.0.11)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pycocotools) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->thop) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yolox 0.3.0 requires onnx-simplifier==0.3.5, which is not installed.
# yolox 0.3.0 requires onnxruntime==1.8.0, which is not installed.
# yolox 0.3.0 requires onnx==1.8.1, but you have onnx 1.20.1 which is incompatible.
# Successfully installed thop-0.1.1.post2209072238

# %%
# !pip install paddlepaddle==2.6.2
# Out:
# Collecting paddlepaddle==2.6.2
#   Downloading paddlepaddle-2.6.2-cp312-cp312-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from paddlepaddle==2.6.2) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from paddlepaddle==2.6.2) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from paddlepaddle==2.6.2) (11.3.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from paddlepaddle==2.6.2) (4.4.2)
# Collecting astor (from paddlepaddle==2.6.2)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle==2.6.2)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from paddlepaddle==2.6.2) (5.29.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->paddlepaddle==2.6.2) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->paddlepaddle==2.6.2) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->paddlepaddle==2.6.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->paddlepaddle==2.6.2) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->paddlepaddle==2.6.2) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->paddlepaddle==2.6.2) (4.15.0)
# Downloading paddlepaddle-2.6.2-cp312-cp312-manylinux1_x86_64.whl (125.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 8.0 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.9 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: opt-einsum, astor, paddlepaddle
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddlepaddle-2.6.2

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# %cd OpenGait/demo
# !mkdir -p checkpoints/bytetrack_model
# !mkdir -p checkpoints/gait_model
# !mkdir -p checkpoints/seg_model
# Out:
# /content/All-in-One-Gait/OpenGait/demo

# %%
# %cd checkpoints/gait_model
# !wget https://github.com/ShiqiYu/OpenGait/releases/download/v2.0/pretrained_grew_gaitbase.zip
# !unzip -j pretrained_grew_gaitbase.zip
# Out:
# /content/All-in-One-Gait/OpenGait/demo/checkpoints/gait_model
# --2026-03-20 19:26:48--  https://github.com/ShiqiYu/OpenGait/releases/download/v2.0/pretrained_grew_gaitbase.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/418159211/fb4cdbf5-c7a1-46cb-9008-763224d92081?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-20T20%3A13%3A56Z&rscd=attachment%3B+filename%3Dpretrained_grew_gaitbase.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-20T19%3A13%3A49Z&ske=2026-03-20T20%3A13%3A56Z&sks=b&skv=2018-11-09&sig=clArOe19NaVuvf16gJoSIGfH1yRQ9xoFSywwz7Ph8Tk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDAzODQwOCwibmJmIjoxNzc0MDM0ODA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ZojFNJ1rsAf0ebEgWp2Y9Ya9EYzB1B1OjX1bwTeci04&response-content-disposition=attachment%3B%20filename%3Dpretrained_grew_gaitbase.zip&response-content-type=application%2Foctet-stream [following]
# --2026-03-20 19:26:48--  https://release-assets.githubusercontent.com/github-production-release-asset/418159211/fb4cdbf5-c7a1-46cb-9008-763224d92081?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-20T20%3A13%3A56Z&rscd=attachment%3B+filename%3Dpretrained_grew_gaitbase.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-20T19%3A13%3A49Z&ske=2026-03-20T20%3A13%3A56Z&sks=b&skv=2018-11-09&sig=clArOe19NaVuvf16gJoSIGfH1yRQ9xoFSywwz7Ph8Tk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDAzODQwOCwibmJmIjoxNzc0MDM0ODA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ZojFNJ1rsAf0ebEgWp2Y9Ya9EYzB1B1OjX1bwTeci04&response-content-disposition=attachment%3B%20filename%3Dpretrained_grew_gaitbase.zip&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 329561273 (314M) [application/octet-stream]
# Saving to: ‘pretrained_grew_gaitbase.zip’
#
# pretrained_grew_gai 100%[===================>] 314.29M  7.73MB/s    in 33s
#
# 2026-03-20 19:27:22 (9.55 MB/s) - ‘pretrained_grew_gaitbase.zip’ saved [329561273/329561273]
#
# Archive:  pretrained_grew_gaitbase.zip
#   inflating: GaitBase_DA-180000.pt

# %%
# %cd ../bytetrack_model
# !pip install --upgrade --no-cache-dir gdown
# !gdown https://drive.google.com/uc?id=1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5
# Out:
# /content/All-in-One-Gait/OpenGait/demo/checkpoints/bytetrack_model
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.25.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5
# From (redirected): https://drive.google.com/uc?id=1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5&confirm=t&uuid=0e159e20-deb2-4b30-94c7-4eda3df66aa8
# To: /content/All-in-One-Gait/OpenGait/demo/checkpoints/bytetrack_model/bytetrack_x_mot17.pth.tar
# 100% 793M/793M [00:07<00:00, 108MB/s]

# %%
# %cd ../seg_model
# !wget https://paddleseg.bj.bcebos.com/dygraph/pp_humanseg_v2/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
# !unzip human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
# Out:
# /content/All-in-One-Gait/OpenGait/demo/checkpoints/seg_model
# --2026-03-20 19:27:48--  https://paddleseg.bj.bcebos.com/dygraph/pp_humanseg_v2/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
# Resolving paddleseg.bj.bcebos.com (paddleseg.bj.bcebos.com)... 103.235.47.176, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddleseg.bj.bcebos.com (paddleseg.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28036186 (27M) [application/zip]
# Saving to: ‘human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip’
#
# human_pp_humansegv2 100%[===================>]  26.74M  19.7MB/s    in 1.4s
#
# 2026-03-20 19:27:50 (19.7 MB/s) - ‘human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip’ saved [28036186/28036186]
#
# Archive:  human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
#    creating: human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/
#   inflating: __MACOSX/._human_pp_humansegv2_mobile_192x192_inference_model_with_softmax
#   inflating: human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/model.pdmodel
#   inflating: __MACOSX/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/._model.pdmodel
#   inflating: human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/model.pdiparams.info
#   inflating: __MACOSX/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/._model.pdiparams.info
#   inflating: human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/model.pdiparams
#   inflating: __MACOSX/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/._model.pdiparams
#   inflating: human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/deploy.yaml
#   inflating: __MACOSX/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/._deploy.yaml

# %%
# %cd /content/All-in-One-Gait/OpenGait
# Out:
# /content/All-in-One-Gait/OpenGait

# %%
# !ls demo/output/InputVideos
# Out:
# gallery.mp4  probe1.mp4  probe2.mp4  probe3.mp4  probe4.mp4

# %%
import pathlib

file_path = pathlib.Path("demo/libs/paddle/infer.py")
text = file_path.read_text()

text = text.replace(
    "import paddle.fluid.core as core",
    "try:\n    import paddle.fluid.core as core\nexcept:\n    from paddle.base import core"
)

file_path.write_text(text)

print("Patch applied.")
# Out:
# Patch applied.

# %%
import numpy as np

# restore deprecated numpy aliases
np.float = float
np.int = int
np.bool = bool
np.object = object

import runpy
_ = runpy.run_path("demo/libs/main.py", run_name="__main__")
# Out:
# /content/All-in-One-Gait/OpenGait/demo/libs/paddle/paddleseg/models/losses/rmi_loss.py:76: SyntaxWarning: invalid escape sequence '\i'
#   logits (Tensor): Shape is [N, C, H, W], logits at each prediction (between -\infty and +\infty).
# 2026-03-20 19:28:06.257 | INFO     | track:loadckpt:47 - Model Summary: Params: 99.00M, Gflops: 793.21
# 2026-03-20 19:28:06.261 | INFO     | track:loadckpt:50 - loading checkpoint
# 2026-03-20 19:28:07.131 | INFO     | track:loadckpt:53 - loaded checkpoint done.
# 2026-03-20 19:28:07.132 | INFO     | track:loadckpt:55 - 	Fusing model...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:974: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:492.)
#   param_grad = param.grad
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/gallery.mp4
# 100%|██████████| 235/235 [00:44<00:00,  5.23it/s]
# 2026-03-20 19:28:59.476 | INFO     | track:track:147 - save results to ./demo/output/OutputVideos/2026_03_20_19_28_14/gallery.txt
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/probe1.mp4
# 100%|██████████| 221/221 [00:44<00:00,  5.00it/s]
# 2026-03-20 19:29:43.693 | INFO     | track:track:147 - save results to ./demo/output/OutputVideos/2026_03_20_19_28_14/probe1.txt
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/probe2.mp4
# 100%|██████████| 257/257 [00:49<00:00,  5.15it/s]
# 2026-03-20 19:30:33.645 | INFO     | track:track:147 - save results to ./demo/output/OutputVideos/2026_03_20_19_28_14/probe2.txt
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/probe3.mp4
# 100%|██████████| 212/212 [00:41<00:00,  5.11it/s]
# 2026-03-20 19:31:15.142 | INFO     | track:track:147 - save results to ./demo/output/OutputVideos/2026_03_20_19_28_14/probe3.txt
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/probe4.mp4
# 100%|██████████| 161/161 [00:34<00:00,  4.72it/s]
# 2026-03-20 19:31:49.251 | INFO     | track:track:147 - save results to ./demo/output/OutputVideos/2026_03_20_19_28_14/probe4.txt
# True
# 2026-03-20 19:31:49.640 | INFO     | recognise:extract_sil:95 - begin extracting
# 2026-03-20 19:31:52.465 | INFO     | recognise:extract_sil:97 - extract Done
# 2026-03-20 19:31:52.466 | INFO     | recognise:extract_sil:95 - begin extracting
# 2026-03-20 19:31:54.978 | INFO     | recognise:extract_sil:97 - extract Done
# 2026-03-20 19:31:54.980 | INFO     | recognise:extract_sil:95 - begin extracting
# 2026-03-20 19:31:58.129 | INFO     | recognise:extract_sil:97 - extract Done
# 2026-03-20 19:31:58.130 | INFO     | recognise:extract_sil:95 - begin extracting
# 2026-03-20 19:32:00.535 | INFO     | recognise:extract_sil:97 - extract Done
# 2026-03-20 19:32:00.536 | INFO     | recognise:extract_sil:95 - begin extracting
# 2026-03-20 19:32:02.495 | INFO     | recognise:extract_sil:97 - extract Done
# 2026-03-20 19:32:02.496 | INFO     | recognise:compare:110 - begin recognising
# 2026-03-20 19:32:02.549 | INFO     | recognise:compare:112 - recognise Done
# 2026-03-20 19:32:02.550 | INFO     | recognise:compare:110 - begin recognising
# 2026-03-20 19:32:02.555 | INFO     | recognise:compare:112 - recognise Done
# 2026-03-20 19:32:02.556 | INFO     | recognise:compare:110 - begin recognising
# 2026-03-20 19:32:02.560 | INFO     | recognise:compare:112 - recognise Done
# 2026-03-20 19:32:02.561 | INFO     | recognise:compare:110 - begin recognising
# 2026-03-20 19:32:02.566 | INFO     | recognise:compare:112 - recognise Done
# ================= probe - gallery ===================
# {'probe1-001': 'gallery-004', 'probe1-003': 'gallery-002', 'probe1-002': 'gallery-003', 'probe1-004': 'gallery-001'}
# ================= probe - gallery ===================
# {'probe2-001': 'gallery-002', 'probe2-003': 'gallery-003', 'probe2-002': 'gallery-004', 'probe2-004': 'gallery-001'}
# ================= probe - gallery ===================
# {'probe3-001': 'gallery-002', 'probe3-003': 'gallery-004', 'probe3-002': 'gallery-003', 'probe3-004': 'gallery-001'}
# ================= probe - gallery ===================
# {'probe4-001': 'gallery-004', 'probe4-003': 'gallery-004', 'probe4-002': 'gallery-003', 'probe4-004': 'gallery-004'}
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe1.mp4
# 100%|██████████| 221/221 [00:46<00:00,  4.78it/s]
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe2.mp4
# 100%|██████████| 257/257 [00:51<00:00,  5.01it/s]
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe3.mp4
# 100%|██████████| 212/212 [00:41<00:00,  5.06it/s]
# video save_path is ./demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe4.mp4
# 100%|██████████| 161/161 [00:33<00:00,  4.83it/s]

# %%
import os, glob

out_root = "demo/output/OutputVideos"
runs = sorted(glob.glob(out_root+"/*"))
print("Runs:", runs[-3:])

latest = runs[-1]
print("Latest run folder:", latest)

print("\nMP4 files:")
for p in sorted(glob.glob(latest+"/*.mp4")):
    print(" -", p)

print("\nTXT files:")
for p in sorted(glob.glob(latest+"/*.txt")):
    print(" -", p)
# Out:
# Runs: ['demo/output/OutputVideos/2026_03_20_19_28_14']
# Latest run folder: demo/output/OutputVideos/2026_03_20_19_28_14
#
# MP4 files:
#  - demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe1.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe2.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe3.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe4.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/gallery.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe1.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe2.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe3.mp4
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe4.mp4
#
# TXT files:
#  - demo/output/OutputVideos/2026_03_20_19_28_14/gallery.txt
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe1.txt
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe2.txt
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe3.txt
#  - demo/output/OutputVideos/2026_03_20_19_28_14/probe4.txt

# %%
import glob

runs = sorted(glob.glob("demo/output/OutputVideos/*"))
latest = runs[-1]
print("Latest run folder:\n", latest)
# Out:
# Latest run folder:
#  demo/output/OutputVideos/2026_03_20_19_28_14

# %%
import glob

videos = sorted(glob.glob(latest + "/*.mp4"))
for v in videos:
    print(v)
# Out:
# demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe1.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe2.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe3.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/G-gallery_P-probe4.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/gallery.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/probe1.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/probe2.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/probe3.mp4
# demo/output/OutputVideos/2026_03_20_19_28_14/probe4.mp4

# %%
import glob

sil_dirs = glob.glob("demo/output/**/*Sil*", recursive=True)
print(sil_dirs)
# Out:
# ['demo/output/GaitSilhouette']

# %%
import os

for root, dirs, files in os.walk("demo/output/GaitSilhouette"):
    print("\n", root)
    print(" Subfolders:", dirs)
    print(" Files:", len(files))
# Out:
#  demo/output/GaitSilhouette
#  Subfolders: ['probe4', 'gallery', 'probe2', 'probe1', 'probe3']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4
#  Subfolders: ['001', '003', '002', '004']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4/001
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4/001/undefined
#  Subfolders: []
#  Files: 41
#
#  demo/output/GaitSilhouette/probe4/003
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4/003/undefined
#  Subfolders: []
#  Files: 41
#
#  demo/output/GaitSilhouette/probe4/002
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4/002/undefined
#  Subfolders: []
#  Files: 25
#
#  demo/output/GaitSilhouette/probe4/004
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe4/004/undefined
#  Subfolders: []
#  Files: 28
#
#  demo/output/GaitSilhouette/gallery
#  Subfolders: ['001', '003', '002', '004']
#  Files: 0
#
#  demo/output/GaitSilhouette/gallery/001
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/gallery/001/undefined
#  Subfolders: []
#  Files: 59
#
#  demo/output/GaitSilhouette/gallery/003
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/gallery/003/undefined
#  Subfolders: []
#  Files: 59
#
#  demo/output/GaitSilhouette/gallery/002
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/gallery/002/undefined
#  Subfolders: []
#  Files: 59
#
#  demo/output/GaitSilhouette/gallery/004
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/gallery/004/undefined
#  Subfolders: []
#  Files: 59
#
#  demo/output/GaitSilhouette/probe2
#  Subfolders: ['001', '003', '002', '004']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe2/001
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe2/001/undefined
#  Subfolders: []
#  Files: 65
#
#  demo/output/GaitSilhouette/probe2/003
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe2/003/undefined
#  Subfolders: []
#  Files: 65
#
#  demo/output/GaitSilhouette/probe2/002
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe2/002/undefined
#  Subfolders: []
#  Files: 65
#
#  demo/output/GaitSilhouette/probe2/004
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe2/004/undefined
#  Subfolders: []
#  Files: 65
#
#  demo/output/GaitSilhouette/probe1
#  Subfolders: ['001', '003', '002', '004']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe1/001
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe1/001/undefined
#  Subfolders: []
#  Files: 56
#
#  demo/output/GaitSilhouette/probe1/003
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe1/003/undefined
#  Subfolders: []
#  Files: 56
#
#  demo/output/GaitSilhouette/probe1/002
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe1/002/undefined
#  Subfolders: []
#  Files: 56
#
#  demo/output/GaitSilhouette/probe1/004
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe1/004/undefined
#  Subfolders: []
#  Files: 56
#
#  demo/output/GaitSilhouette/probe3
#  Subfolders: ['001', '003', '002', '004']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe3/001
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe3/001/undefined
#  Subfolders: []
#  Files: 53
#
#  demo/output/GaitSilhouette/probe3/003
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe3/003/undefined
#  Subfolders: []
#  Files: 53
#
#  demo/output/GaitSilhouette/probe3/002
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe3/002/undefined
#  Subfolders: []
#  Files: 53
#
#  demo/output/GaitSilhouette/probe3/004
#  Subfolders: ['undefined']
#  Files: 0
#
#  demo/output/GaitSilhouette/probe3/004/undefined
#  Subfolders: []
#  Files: 53

# %%
from IPython.display import Image, display
import glob

sil_images = sorted(glob.glob(
    "demo/output/GaitSilhouette/gallery/001/undefined/*.png"
))

print("Total frames:", len(sil_images))

display(Image(sil_images[0]))
display(Image(sil_images[len(sil_images)//2]))
display(Image(sil_images[-1]))
# Out:
# Total frames: 59

# %%
# !pip install -q kagglehub

import kagglehub

path = kagglehub.dataset_download("trnquanghuyn/casia-b")
print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/1.archive...
# 100%|██████████| 728M/728M [00:44<00:00, 17.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1

# %%
import os

for root, dirs, files in os.walk(path):
    print(root)
    print("dirs:", dirs[:5])
    print("files:", files[:5])
    print("-" * 60)
    if root.count(os.sep) - path.count(os.sep) > 2:
        break
# Out:
# /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1
# dirs: ['output']
# files: []
# ------------------------------------------------------------
# /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1/output
# dirs: ['058', '052', '087', '096', '104']
# files: []
# ------------------------------------------------------------
# /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1/output/058
# dirs: ['cl-01', 'nm-01', 'nm-05', 'nm-02', 'bg-02']
# files: []
# ------------------------------------------------------------
# /root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1/output/058/cl-01
# dirs: ['072', '090', '108', '144', '018']
# files: []
# ------------------------------------------------------------

# %%
CASIA_RAW_ROOT = "/root/.cache/kagglehub/datasets/trnquanghuyn/casia-b/versions/1/output"

# %cd /content/All-in-One-Gait
# !rm -rf casiab
# !cp -r "{CASIA_RAW_ROOT}" ./casiab

# !find /content/All-in-One-Gait/casiab -maxdepth 3 | head -40
# Out:
# /content/All-in-One-Gait
# /content/All-in-One-Gait/casiab
# /content/All-in-One-Gait/casiab/058
# /content/All-in-One-Gait/casiab/058/cl-01
# /content/All-in-One-Gait/casiab/058/cl-01/072
# /content/All-in-One-Gait/casiab/058/cl-01/090
# /content/All-in-One-Gait/casiab/058/cl-01/108
# /content/All-in-One-Gait/casiab/058/cl-01/144
# /content/All-in-One-Gait/casiab/058/cl-01/018
# /content/All-in-One-Gait/casiab/058/cl-01/180
# /content/All-in-One-Gait/casiab/058/cl-01/126
# /content/All-in-One-Gait/casiab/058/cl-01/000
# /content/All-in-One-Gait/casiab/058/cl-01/036
# /content/All-in-One-Gait/casiab/058/cl-01/054
# /content/All-in-One-Gait/casiab/058/cl-01/162
# /content/All-in-One-Gait/casiab/058/nm-01
# /content/All-in-One-Gait/casiab/058/nm-01/072
# /content/All-in-One-Gait/casiab/058/nm-01/090
# /content/All-in-One-Gait/casiab/058/nm-01/108
# /content/All-in-One-Gait/casiab/058/nm-01/144
# /content/All-in-One-Gait/casiab/058/nm-01/018
# /content/All-in-One-Gait/casiab/058/nm-01/180
# /content/All-in-One-Gait/casiab/058/nm-01/126
# /content/All-in-One-Gait/casiab/058/nm-01/000
# /content/All-in-One-Gait/casiab/058/nm-01/036
# /content/All-in-One-Gait/casiab/058/nm-01/054
# /content/All-in-One-Gait/casiab/058/nm-01/162
# /content/All-in-One-Gait/casiab/058/nm-05
# /content/All-in-One-Gait/casiab/058/nm-05/072
# /content/All-in-One-Gait/casiab/058/nm-05/090
# /content/All-in-One-Gait/casiab/058/nm-05/108
# /content/All-in-One-Gait/casiab/058/nm-05/144
# /content/All-in-One-Gait/casiab/058/nm-05/018
# /content/All-in-One-Gait/casiab/058/nm-05/180
# /content/All-in-One-Gait/casiab/058/nm-05/126
# /content/All-in-One-Gait/casiab/058/nm-05/000
# /content/All-in-One-Gait/casiab/058/nm-05/036
# /content/All-in-One-Gait/casiab/058/nm-05/054
# /content/All-in-One-Gait/casiab/058/nm-05/162
# /content/All-in-One-Gait/casiab/058/nm-02
# /content/All-in-One-Gait/casiab/058/nm-02/072

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !python datasets/pretreatment.py \
    --input_path /content/All-in-One-Gait/casiab \
    --output_path /content/All-in-One-Gait/casiab-pkl \
    --dataset CASIAB \
    --img_size 64 \
    --n_workers 4
# Out:
# /content/All-in-One-Gait/OpenGait
# Pretreating: 100% 13592/13592 [07:54<00:00, 28.64folder/s]

# %%
from pathlib import Path

def replace_once(path, old, new):
    path = Path(path)
    text = path.read_text()
    if old in text:
        text = text.replace(old, new)
        path.write_text(text)
        print("patched:", path)
    else:
        print("skip:", path)

REPO = Path("/content/All-in-One-Gait/OpenGait")

replace_once(
    REPO / "opengait/modeling/base_model.py",
    """        # self.save_path = osp.join('output/', cfgs['data_cfg']['dataset_name'],
        #                           cfgs['model_cfg']['model'], self.engine_cfg['save_name'])
        # self.save_path = "/home/jdy/Gaitdateset/gait_model/Baseline-150000.pt"
        self.save_path = "/home/jdy/Gaitdateset/gait_model/Baseline-60000.pt"
""",
    """        self.save_path = osp.join(
            'output/',
            cfgs['data_cfg']['dataset_name'],
            cfgs['model_cfg']['model'],
            self.engine_cfg['save_name'],
        )
"""
)

replace_once(
    REPO / "opengait/modeling/base_model.py",
    """        # self._load_ckpt(save_name)
        self._load_ckpt(self.save_path)
""",
    """        self._load_ckpt(save_name)
"""
)

replace_once(
    REPO / "opengait/utils/common.py",
    """def ts2var(x, **kwargs):
    return autograd.Variable(x, **kwargs).cuda()
""",
    """def ts2var(x, **kwargs):
    var = autograd.Variable(x, **kwargs)
    if torch.cuda.is_available():
        return var.cuda()
    return var
"""
)

replace_once(
    REPO / "opengait/utils/common.py",
    """def MeanIOU(msk1, msk2, eps=1.0e-9):
    if not is_tensor(msk1):
        msk1 = torch.from_numpy(msk1).cuda()
    if not is_tensor(msk2):
        msk2 = torch.from_numpy(msk2).cuda()
""",
    """def MeanIOU(msk1, msk2, eps=1.0e-9):
    if not is_tensor(msk1):
        msk1 = torch.from_numpy(msk1)
    if not is_tensor(msk2):
        msk2 = torch.from_numpy(msk2)
    if torch.cuda.is_available():
        msk1 = msk1.cuda()
        msk2 = msk2.cuda()
"""
)

replace_once(
    REPO / "opengait/utils/msg_manager.py",
    "from time import strftime, localtime\n\nfrom torch.utils.tensorboard import SummaryWriter\n",
    "from time import strftime, localtime\nfrom PIL import Image\n\nfrom torch.utils.tensorboard import SummaryWriter\n"
)

replace_once(
    REPO / "opengait/utils/msg_manager.py",
    "import logging\n\n\nclass MessageManager:\n",
    "import logging\n\n\nif not hasattr(Image, 'ANTIALIAS') and hasattr(Image, 'Resampling'):\n    Image.ANTIALIAS = Image.Resampling.LANCZOS\n\n\nclass MessageManager:\n"
)
# Out:
# patched: /content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py
# patched: /content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py
# patched: /content/All-in-One-Gait/OpenGait/opengait/utils/common.py
# patched: /content/All-in-One-Gait/OpenGait/opengait/utils/common.py
# patched: /content/All-in-One-Gait/OpenGait/opengait/utils/msg_manager.py
# patched: /content/All-in-One-Gait/OpenGait/opengait/utils/msg_manager.py

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !mkdir -p pretrained_assets output
# !wget -O pretrained_assets/pretrained_casiab_model.zip https://github.com/ShiqiYu/OpenGait/releases/download/v1.0/pretrained_casiab_model.zip
# !unzip -o pretrained_assets/pretrained_casiab_model.zip -d output

# !find output/CASIA-B -maxdepth 5 -type f | sort
# Out:
# /content/All-in-One-Gait/OpenGait
# --2026-03-20 20:02:59--  https://github.com/ShiqiYu/OpenGait/releases/download/v1.0/pretrained_casiab_model.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/418159211/2cac294b-e2cc-4826-b432-bacac4ec6387?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-20T20%3A54%3A53Z&rscd=attachment%3B+filename%3Dpretrained_casiab_model.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-20T19%3A54%3A31Z&ske=2026-03-20T20%3A54%3A53Z&sks=b&skv=2018-11-09&sig=jZyx%2FWgWUWszHdc7U4%2BGa4%2BaQDX6kUyf1OXF5DCM53w%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDA0MDU3OSwibmJmIjoxNzc0MDM2OTc5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.0ns7a0pvDwqisP5h8AXiPvk6BaXblzSZ2QdLNiJhkTs&response-content-disposition=attachment%3B%20filename%3Dpretrained_casiab_model.zip&response-content-type=application%2Foctet-stream [following]
# --2026-03-20 20:02:59--  https://release-assets.githubusercontent.com/github-production-release-asset/418159211/2cac294b-e2cc-4826-b432-bacac4ec6387?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-20T20%3A54%3A53Z&rscd=attachment%3B+filename%3Dpretrained_casiab_model.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-20T19%3A54%3A31Z&ske=2026-03-20T20%3A54%3A53Z&sks=b&skv=2018-11-09&sig=jZyx%2FWgWUWszHdc7U4%2BGa4%2BaQDX6kUyf1OXF5DCM53w%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDA0MDU3OSwibmJmIjoxNzc0MDM2OTc5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.0ns7a0pvDwqisP5h8AXiPvk6BaXblzSZ2QdLNiJhkTs&response-content-disposition=attachment%3B%20filename%3Dpretrained_casiab_model.zip&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267622961 (255M) [application/octet-stream]
# Saving to: ‘pretrained_assets/pretrained_casiab_model.zip’
#
# pretrained_assets/p 100%[===================>] 255.22M  8.70MB/s    in 38s
#
# 2026-03-20 20:03:38 (6.73 MB/s) - ‘pretrained_assets/pretrained_casiab_model.zip’ saved [267622961/267622961]
#
# Archive:  pretrained_assets/pretrained_casiab_model.zip
#    creating: output/CASIA-B/Baseline/
#    creating: output/CASIA-B/Baseline/Baseline/
#    creating: output/CASIA-B/Baseline/Baseline/checkpoints/
#   inflating: output/CASIA-B/Baseline/Baseline/checkpoints/Baseline-60000.pt
#    creating: output/CASIA-B/GaitGL/
#    creating: output/CASIA-B/GaitGL/GaitGL/
#    creating: output/CASIA-B/GaitGL/GaitGL/checkpoints/
#   inflating: output/CASIA-B/GaitGL/GaitGL/checkpoints/GaitGL-80000.pt
#    creating: output/CASIA-B/GaitPart/
#    creating: output/CASIA-B/GaitPart/GaitPart/
#    creating: output/CASIA-B/GaitPart/GaitPart/checkpoints/
#   inflating: output/CASIA-B/GaitPart/GaitPart/checkpoints/GaitPart-120000.pt
#    creating: output/CASIA-B/GaitSet/
#    creating: output/CASIA-B/GaitSet/GaitSet/
#    creating: output/CASIA-B/GaitSet/GaitSet/checkpoints/
#   inflating: output/CASIA-B/GaitSet/GaitSet/checkpoints/GaitSet-40000.pt
#    creating: output/CASIA-B/GLN/
#    creating: output/CASIA-B/GLN/GLN_P1/
#    creating: output/CASIA-B/GLN/GLN_P1/checkpoints/
#   inflating: output/CASIA-B/GLN/GLN_P1/checkpoints/GLN_P1-40000.pt
#    creating: output/CASIA-B/GLN/GLN_P2/
#    creating: output/CASIA-B/GLN/GLN_P2/checkpoints/
#   inflating: output/CASIA-B/GLN/GLN_P2/checkpoints/GLN_P2-40000.pt
# output/CASIA-B/Baseline/Baseline/checkpoints/Baseline-60000.pt
# output/CASIA-B/GaitGL/GaitGL/checkpoints/GaitGL-80000.pt
# output/CASIA-B/GaitPart/GaitPart/checkpoints/GaitPart-120000.pt
# output/CASIA-B/GaitSet/GaitSet/checkpoints/GaitSet-40000.pt
# output/CASIA-B/GLN/GLN_P1/checkpoints/GLN_P1-40000.pt
# output/CASIA-B/GLN/GLN_P2/checkpoints/GLN_P2-40000.pt

# %%
from pathlib import Path

cfg_dir = Path("/content/All-in-One-Gait/OpenGait/configs/colab")
cfg_dir.mkdir(parents=True, exist_ok=True)

baseline_cfg = """
data_cfg:
  dataset_name: CASIA-B
  dataset_root: /content/All-in-One-Gait/casiab-pkl
  dataset_partition: /content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json
  num_workers: 2
  cache: false
  remove_no_gallery: false
  test_dataset_name: CASIA-B

evaluator_cfg:
  enable_float16: true
  restore_ckpt_strict: true
  restore_hint: 60000
  save_name: Baseline
  eval_func: evaluate_indoor_dataset
  sampler:
    batch_shuffle: false
    batch_size: 16
    sample_type: all_ordered
    type: InferenceSampler
    frames_all_limit: 720
  metric: euc
  transform:
    - type: BaseSilCuttingTransform
      img_w: 64
  cross_view_gallery: false

loss_cfg:
  - loss_term_weight: 1.0
    margin: 0.2
    type: TripletLoss
    log_prefix: triplet
  - loss_term_weight: 0.1
    scale: 16
    type: CrossEntropyLoss
    log_prefix: softmax
    log_accuracy: true

model_cfg:
  model: Baseline
  backbone_cfg:
    in_channels: 1
    layers_cfg:
      - BC-64
      - BC-64
      - M
      - BC-128
      - BC-128
      - M
      - BC-256
      - BC-256
    type: Plain
  SeparateFCs:
    in_channels: 256
    out_channels: 256
    parts_num: 31
  SeparateBNNecks:
    class_num: 74
    in_channels: 256
    parts_num: 31
  bin_num:
    - 16
    - 8
    - 4
    - 2
    - 1

optimizer_cfg:
  lr: 0.1
  momentum: 0.9
  solver: SGD
  weight_decay: 0.0005

scheduler_cfg:
  gamma: 0.1
  milestones:
    - 20000
    - 40000
  scheduler: MultiStepLR

trainer_cfg:
  enable_float16: true
  fix_BN: false
  log_iter: 100
  with_test: true
  restore_ckpt_strict: true
  restore_hint: 0
  save_iter: 10000
  save_name: Baseline
  sync_BN: false
  total_iter: 60000
  sampler:
    batch_shuffle: true
    batch_size:
      - 8
      - 16
    frames_num_fixed: 30
    frames_num_max: 50
    frames_num_min: 25
    sample_type: fixed_unordered
    type: TripletSampler
  transform:
    - type: BaseSilCuttingTransform
      img_w: 64
"""

gaitset_cfg = """
data_cfg:
  dataset_name: CASIA-B
  dataset_root: /content/All-in-One-Gait/casiab-pkl
  dataset_partition: /content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json
  num_workers: 2
  cache: false
  remove_no_gallery: false
  test_dataset_name: CASIA-B

evaluator_cfg:
  enable_float16: true
  restore_ckpt_strict: true
  restore_hint: 40000
  save_name: GaitSet
  eval_func: evaluate_indoor_dataset
  sampler:
    batch_size: 16
    sample_type: all_ordered
    type: InferenceSampler
  metric: euc
  cross_view_gallery: false

loss_cfg:
  loss_term_weight: 1.0
  margin: 0.2
  type: TripletLoss
  log_prefix: triplet

model_cfg:
  model: GaitSet
  in_channels:
    - 1
    - 32
    - 64
    - 128
  SeparateFCs:
    in_channels: 128
    out_channels: 256
    parts_num: 62
  bin_num:
    - 16
    - 8
    - 4
    - 2
    - 1

optimizer_cfg:
  lr: 0.1
  momentum: 0.9
  solver: SGD
  weight_decay: 0.0005

scheduler_cfg:
  gamma: 0.1
  milestones:
    - 10000
    - 20000
    - 30000
  scheduler: MultiStepLR

trainer_cfg:
  enable_float16: true
  log_iter: 100
  with_test: true
  restore_ckpt_strict: true
  restore_hint: 0
  save_iter: 10000
  save_name: GaitSet
  sync_BN: false
  total_iter: 40000
  sampler:
    batch_shuffle: false
    batch_size:
      - 8
      - 16
    frames_num_fixed: 30
    frames_num_max: 50
    frames_num_min: 25
    sample_type: fixed_unordered
    type: TripletSampler
"""

gaitgl_cfg = """
data_cfg:
  dataset_name: CASIA-B
  dataset_root: /content/All-in-One-Gait/casiab-pkl
  dataset_partition: /content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json
  num_workers: 2
  cache: false
  remove_no_gallery: false
  test_dataset_name: CASIA-B

evaluator_cfg:
  enable_float16: true
  restore_ckpt_strict: true
  restore_hint: 80000
  save_name: GaitGL
  eval_func: evaluate_indoor_dataset
  sampler:
    batch_size: 1
    sample_type: all_ordered
    type: InferenceSampler
  metric: euc
  cross_view_gallery: false

loss_cfg:
  - loss_term_weight: 1.0
    margin: 0.2
    type: TripletLoss
    log_prefix: triplet
  - loss_term_weight: 1.0
    scale: 1
    type: CrossEntropyLoss
    log_accuracy: true
    label_smooth: false
    log_prefix: softmax

model_cfg:
  model: GaitGL
  channels:
    - 32
    - 64
    - 128
  class_num: 74

optimizer_cfg:
  lr: 1.0e-4
  solver: Adam
  weight_decay: 5.0e-4

scheduler_cfg:
  gamma: 0.1
  milestones:
    - 70000
  scheduler: MultiStepLR

trainer_cfg:
  enable_float16: true
  with_test: true
  log_iter: 100
  restore_ckpt_strict: true
  restore_hint: 0
  save_iter: 10000
  save_name: GaitGL
  sync_BN: true
  total_iter: 80000
  sampler:
    batch_shuffle: true
    batch_size:
      - 8
      - 8
    frames_num_fixed: 30
    frames_skip_num: 0
    sample_type: fixed_ordered
    type: TripletSampler
"""

(cfg_dir / "baseline_casiab_pretrained_colab.yaml").write_text(baseline_cfg)
(cfg_dir / "gaitset_casiab_pretrained_colab.yaml").write_text(gaitset_cfg)
(cfg_dir / "gaitgl_casiab_pretrained_colab.yaml").write_text(gaitgl_cfg)

print("Wrote:")
for p in sorted(cfg_dir.glob("*.yaml")):
    print(p)
# Out:
# Wrote:
# /content/All-in-One-Gait/OpenGait/configs/colab/baseline_casiab_pretrained_colab.yaml
# /content/All-in-One-Gait/OpenGait/configs/colab/gaitgl_casiab_pretrained_colab.yaml
# /content/All-in-One-Gait/OpenGait/configs/colab/gaitset_casiab_pretrained_colab.yaml

# %%
# !pip install -q kornia
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 107.6 MB/s eta 0:00:00

# %%
from pathlib import Path

main_py = Path("/content/All-in-One-Gait/OpenGait/opengait/main.py")
text = main_py.read_text()

if '--local-rank' not in text:
    text = text.replace(
        "parser.add_argument('--local_rank', type=int, default=0, help='local rank for distributed training')",
        "parser.add_argument('--local_rank', '--local-rank', dest='local_rank', type=int, default=0, help='local rank for distributed training')"
    )
    main_py.write_text(text)
    print("patched main.py")
else:
    print("main.py already patched")
# Out:
# patched main.py

# %%
from pathlib import Path

main_py = Path("/content/All-in-One-Gait/OpenGait/opengait/main.py")
text = main_py.read_text()

old = """parser.add_argument('--local_rank', type=int, default=0,
                    help="passed by torch.distributed.launch module")
"""

new = """parser.add_argument('--local_rank', '--local-rank', dest='local_rank', type=int, default=0,
                    help="passed by torch.distributed.launch module")
"""

if old in text:
    text = text.replace(old, new)
    main_py.write_text(text)
    print("patched main.py successfully")
else:
    print("expected parser block not found, printing current parser section:")
    for line in text.splitlines()[:20]:
        print(line)
# Out:
# patched main.py successfully

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --master_port 29511 --nproc_per_node=1 opengait/main.py --cfgs ./configs/colab/baseline_casiab_pretrained_colab.yaml --phase test --iter 60000
# Out:
# /content/All-in-One-Gait/OpenGait
# /usr/local/lib/python3.12/dist-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2026-03-20 20:13:57.676689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774037637.696323   14752 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774037637.702469   14752 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774037637.720523   14752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774037637.720570   14752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774037637.720575   14752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774037637.720579   14752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [2026-03-20 20:14:03] [INFO]: {'enable_float16': True, 'restore_ckpt_strict': True, 'restore_hint': 60000, 'save_name': 'Baseline', 'eval_func': 'evaluate_indoor_dataset', 'sampler': {'batch_size': 16, 'sample_type': 'all_ordered', 'type': 'InferenceSampler', 'batch_shuffle': False, 'frames_all_limit': 720}, 'transform': [{'type': 'BaseSilCuttingTransform', 'img_w': 64}], 'metric': 'euc', 'cross_view_gallery': False}
# [2026-03-20 20:14:03] [INFO]: {'model': 'Baseline', 'backbone_cfg': {'in_channels': 1, 'layers_cfg': ['BC-64', 'BC-64', 'M', 'BC-128', 'BC-128', 'M', 'BC-256', 'BC-256'], 'type': 'Plain'}, 'SeparateFCs': {'in_channels': 256, 'out_channels': 256, 'parts_num': 31}, 'SeparateBNNecks': {'class_num': 74, 'in_channels': 256, 'parts_num': 31}, 'bin_num': [16, 8, 4, 2, 1]}
# [2026-03-20 20:14:03] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': '/content/All-in-One-Gait/casiab-pkl', 'num_workers': 2, 'dataset_partition': '/content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2026-03-20 20:14:03] [INFO]: -------- Test Pid List --------
# [2026-03-20 20:14:03] [INFO]: [075, 076, ..., 124]
# [2026-03-20 20:14:04] [INFO]: Restore Parameters from output/CASIA-B/Baseline/Baseline/checkpoints/Baseline-60000.pt !!!
# [2026-03-20 20:14:05] [INFO]: Parameters Count: 3.77914M
# [2026-03-20 20:14:05] [INFO]: Model Initialization Finished!
# Transforming:   0% 0/5485 [00:00<?, ?it/s]/content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.engine_cfg['enable_float16']):
# Transforming: 100% 5485/5485 [00:57<00:00, 94.98it/s]
# [2026-03-20 20:15:07] [INFO]: ===Rank-1 (Exclude identical-view cases)===
# [2026-03-20 20:15:07] [INFO]: NM: [93.80 98.70 99.80 97.80 94.50 93.20 96.20 97.10 98.90 98.20 91.50]
# [2026-03-20 20:15:07] [INFO]: BG: [91.50 95.40 96.00 93.44 88.60 85.30 88.90 93.80 96.80 97.17 88.00]
# [2026-03-20 20:15:07] [INFO]: CL: [72.70 84.70 84.90 80.30 73.90 74.20 76.70 77.50 80.40 80.50 67.30]
# [2026-03-20 20:15:07] [INFO]: NM: 96.34%	BG: 92.26%	CL: 77.55%
# [rank0]:[W320 20:15:08.276897433 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --master_port 29512 --nproc_per_node=1 opengait/main.py --cfgs ./configs/colab/gaitset_casiab_pretrained_colab.yaml --phase test --iter 40000
# Out:
# /content/All-in-One-Gait/OpenGait
# /usr/local/lib/python3.12/dist-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2026-03-20 20:20:17.456898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774038017.477756   16422 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774038017.484452   16422 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774038017.503071   16422 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038017.503122   16422 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038017.503127   16422 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038017.503131   16422 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [2026-03-20 20:20:24] [INFO]: {'enable_float16': True, 'restore_ckpt_strict': True, 'restore_hint': 40000, 'save_name': 'GaitSet', 'eval_func': 'evaluate_indoor_dataset', 'sampler': {'batch_size': 16, 'sample_type': 'all_ordered', 'type': 'InferenceSampler'}, 'transform': [{'img_w': 64, 'type': 'BaseSilCuttingTransform'}], 'metric': 'euc', 'cross_view_gallery': False}
# [2026-03-20 20:20:24] [INFO]: {'model': 'GaitSet', 'in_channels': [1, 32, 64, 128], 'SeparateFCs': {'in_channels': 128, 'out_channels': 256, 'parts_num': 62}, 'bin_num': [16, 8, 4, 2, 1]}
# [2026-03-20 20:20:24] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': '/content/All-in-One-Gait/casiab-pkl', 'num_workers': 2, 'dataset_partition': '/content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2026-03-20 20:20:24] [INFO]: -------- Test Pid List --------
# [2026-03-20 20:20:24] [INFO]: [075, 076, ..., 124]
# [2026-03-20 20:20:25] [INFO]: Restore Parameters from output/CASIA-B/GaitSet/GaitSet/checkpoints/GaitSet-40000.pt !!!
# [2026-03-20 20:20:25] [INFO]: Parameters Count: 2.59459M
# [2026-03-20 20:20:25] [INFO]: Model Initialization Finished!
# Transforming:   0% 0/5485 [00:00<?, ?it/s]/content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.engine_cfg['enable_float16']):
# Transforming: 100% 5485/5485 [00:34<00:00, 159.41it/s]
# [2026-03-20 20:21:10] [INFO]: ===Rank-1 (Exclude identical-view cases)===
# [2026-03-20 20:21:10] [INFO]: NM: [92.30 98.30 99.30 97.80 94.40 92.00 95.80 97.50 98.50 98.10 90.10]
# [2026-03-20 20:21:10] [INFO]: BG: [88.10 94.30 94.20 91.92 86.00 82.40 86.20 91.30 95.10 95.56 85.10]
# [2026-03-20 20:21:10] [INFO]: CL: [69.00 82.70 85.40 80.40 73.20 69.70 73.30 76.70 77.90 79.00 62.50]
# [2026-03-20 20:21:10] [INFO]: NM: 95.83%	BG: 90.02%	CL: 75.44%
# [rank0]:[W320 20:21:11.660385287 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --master_port 29512 --nproc_per_node=1 opengait/main.py --cfgs ./configs/colab/gaitset_casiab_pretrained_colab.yaml --phase test --iter 40000
# Out:
# /content/All-in-One-Gait/OpenGait
# /usr/local/lib/python3.12/dist-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2026-03-20 20:21:20.753736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774038080.775700   16721 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774038080.782789   16721 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774038080.804617   16721 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038080.804646   16721 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038080.804650   16721 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038080.804653   16721 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [2026-03-20 20:21:26] [INFO]: {'enable_float16': True, 'restore_ckpt_strict': True, 'restore_hint': 40000, 'save_name': 'GaitSet', 'eval_func': 'evaluate_indoor_dataset', 'sampler': {'batch_size': 16, 'sample_type': 'all_ordered', 'type': 'InferenceSampler'}, 'transform': [{'img_w': 64, 'type': 'BaseSilCuttingTransform'}], 'metric': 'euc', 'cross_view_gallery': False}
# [2026-03-20 20:21:26] [INFO]: {'model': 'GaitSet', 'in_channels': [1, 32, 64, 128], 'SeparateFCs': {'in_channels': 128, 'out_channels': 256, 'parts_num': 62}, 'bin_num': [16, 8, 4, 2, 1]}
# [2026-03-20 20:21:26] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': '/content/All-in-One-Gait/casiab-pkl', 'num_workers': 2, 'dataset_partition': '/content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2026-03-20 20:21:26] [INFO]: -------- Test Pid List --------
# [2026-03-20 20:21:26] [INFO]: [075, 076, ..., 124]
# [2026-03-20 20:21:28] [INFO]: Restore Parameters from output/CASIA-B/GaitSet/GaitSet/checkpoints/GaitSet-40000.pt !!!
# [2026-03-20 20:21:28] [INFO]: Parameters Count: 2.59459M
# [2026-03-20 20:21:28] [INFO]: Model Initialization Finished!
# Transforming:   0% 0/5485 [00:00<?, ?it/s]/content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.engine_cfg['enable_float16']):
# Transforming: 100% 5485/5485 [00:31<00:00, 175.11it/s]
# [2026-03-20 20:22:09] [INFO]: ===Rank-1 (Exclude identical-view cases)===
# [2026-03-20 20:22:09] [INFO]: NM: [92.30 98.30 99.30 97.80 94.40 92.00 95.80 97.50 98.50 98.10 90.10]
# [2026-03-20 20:22:09] [INFO]: BG: [88.10 94.30 94.20 91.92 86.00 82.40 86.20 91.30 95.10 95.56 85.10]
# [2026-03-20 20:22:09] [INFO]: CL: [69.00 82.70 85.40 80.40 73.20 69.70 73.30 76.70 77.90 79.00 62.50]
# [2026-03-20 20:22:09] [INFO]: NM: 95.83%	BG: 90.02%	CL: 75.44%
# [rank0]:[W320 20:22:09.543215168 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
# %cd /content/All-in-One-Gait/OpenGait
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --master_port 29513 --nproc_per_node=1 opengait/main.py --cfgs ./configs/colab/gaitgl_casiab_pretrained_colab.yaml --phase test --iter 80000
# Out:
# /content/All-in-One-Gait/OpenGait
# /usr/local/lib/python3.12/dist-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2026-03-20 20:23:17.088472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774038197.122410   17242 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774038197.132966   17242 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774038197.160918   17242 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038197.160952   17242 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038197.160961   17242 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774038197.160968   17242 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [2026-03-20 20:23:23] [INFO]: {'enable_float16': True, 'restore_ckpt_strict': True, 'restore_hint': 80000, 'save_name': 'GaitGL', 'eval_func': 'evaluate_indoor_dataset', 'sampler': {'batch_size': 1, 'sample_type': 'all_ordered', 'type': 'InferenceSampler'}, 'transform': [{'img_w': 64, 'type': 'BaseSilCuttingTransform'}], 'metric': 'euc', 'cross_view_gallery': False}
# [2026-03-20 20:23:23] [INFO]: {'model': 'GaitGL', 'channels': [32, 64, 128], 'class_num': 74}
# [2026-03-20 20:23:23] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': '/content/All-in-One-Gait/casiab-pkl', 'num_workers': 2, 'dataset_partition': '/content/All-in-One-Gait/OpenGait/datasets/CASIA-B/CASIA-B_include_005.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2026-03-20 20:23:23] [INFO]: -------- Test Pid List --------
# [2026-03-20 20:23:23] [INFO]: [075, 076, ..., 124]
# [2026-03-20 20:23:24] [INFO]: Restore Parameters from output/CASIA-B/GaitGL/GaitGL/checkpoints/GaitGL-80000.pt !!!
# [2026-03-20 20:23:24] [INFO]: Parameters Count: 3.09667M
# [2026-03-20 20:23:24] [INFO]: Model Initialization Finished!
# Transforming:   0% 0/5485 [00:00<?, ?it/s]/content/All-in-One-Gait/OpenGait/opengait/modeling/base_model.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.engine_cfg['enable_float16']):
# Transforming: 100% 5485/5485 [00:49<00:00, 111.70it/s]
# [2026-03-20 20:24:22] [INFO]: ===Rank-1 (Exclude identical-view cases)===
# [2026-03-20 20:24:22] [INFO]: NM: [96.20 98.50 99.10 98.00 96.60 95.20 97.30 99.10 98.90 98.80 94.00]
# [2026-03-20 20:24:22] [INFO]: BG: [93.30 96.10 97.10 96.36 94.20 88.80 92.70 95.80 98.00 96.47 91.40]
# [2026-03-20 20:24:22] [INFO]: CL: [77.10 90.40 92.10 90.10 82.80 77.80 81.90 86.30 88.90 84.60 70.60]
# [2026-03-20 20:24:22] [INFO]: NM: 97.43%	BG: 94.57%	CL: 83.87%
# [rank0]:[W320 20:24:23.764955412 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %% [markdown]
# ---
#
# # Final Course Project Extension: Gallery/Probe Entry Recognition
#
# The cells above are preserved from `all_in_one_gait_progress_2.ipynb`.
#
# From here onward, we add the final project workflow:
# - download gallery/probe videos from Google Drive,
# - prepare a clean Pritom/Coco gallery and Test1 probe,
# - run closed-set gait recognition using our final scripts,
# - render an annotated video with names, counts, and similarity scores,
# - optionally launch a Gradio interface.
#
# Closed-set assumption:
# Every person in the probe belongs to one of the gallery identities. If only one gallery identity is uploaded, use the fallback threshold mode in the Gradio app.

# %% [markdown]
# ## Final 1. Move To Repository Root
#
# The progress notebook often works inside `/content/All-in-One-Gait/OpenGait`. Our clean demo scripts live one level above that, under `/content/All-in-One-Gait/clean_demo_v2`.

# %%
from pathlib import Path
import os, json, shutil

ROOT = Path('/content/All-in-One-Gait')
if not ROOT.exists():
    # Local/server fallback if this notebook is inspected outside Colab.
    ROOT = Path('/home/ppaul11/All-in-One-Gait')
os.chdir(ROOT)
print('ROOT:', ROOT)
print('cwd:', Path.cwd())

# %% [markdown]
# ## Final 2. Make Sure Final Dependencies Are Available
#
# Progress 2 already installs most dependencies. This cell adds the final-interface dependency and ensures `gdown` is available for Drive folders.

# %%
# Colab dependency pins for the final demo/app.
# NumPy must stay below 2 because some OpenCV/Paddle wheels used by this project
# are compiled against the NumPy 1.x ABI. Restart runtime after this cell if Colab asks.
# !pip install -q --force-reinstall "numpy<2" "opencv-python-headless>=4.8,<4.11" gdown gradio imageio-ffmpeg

# %% [markdown]
# ## Final 2B. Ensure Required Checkpoints
#
# Run this in a fresh Colab runtime before launching the final scripts/app. It downloads the model and preprocessing weights into the exact folders expected by `clean_demo_v2/gradio_app.py` and the clean demo scripts.
#
# Required for the final app:
# - GREW GaitBase checkpoint
# - ByteTrack checkpoint
# - Human segmentation checkpoint
#
# Optional comparison:
# - GREW GaitGL checkpoint

# %%
from pathlib import Path

ROOT = Path('/content/All-in-One-Gait') if Path('/content/All-in-One-Gait').exists() else Path('/home/ppaul11/All-in-One-Gait')
OPENGAIT = ROOT / 'OpenGait'
# %cd $OPENGAIT

# !mkdir -p demo/checkpoints/gait_model demo/checkpoints/bytetrack_model demo/checkpoints/seg_model demo/output output

# GREW GaitBase, main recommended model.
GaitBase_CKPT = OPENGAIT / 'demo/checkpoints/gait_model/GREW/Baseline/GaitBase_DA/checkpoints/GaitBase_DA-180000.pt'
if not GaitBase_CKPT.exists():
    # !wget -nc -O demo/checkpoints/gait_model/pretrained_grew_gaitbase.zip https://github.com/ShiqiYu/OpenGait/releases/download/v2.0/pretrained_grew_gaitbase.zip
    # !unzip -n demo/checkpoints/gait_model/pretrained_grew_gaitbase.zip -d demo/checkpoints/gait_model/
print('GREW GaitBase exists:', GaitBase_CKPT.exists(), GaitBase_CKPT)

# GREW GaitGL, optional ablation model.
GaitGL_CKPT = OPENGAIT / 'demo/checkpoints/gait_model/GaitGL/checkpoints/GaitGL-250000.pt'
if not GaitGL_CKPT.exists():
    # !wget -nc -O demo/checkpoints/gait_model/pretrained_grew_gaitgl.zip https://github.com/ShiqiYu/OpenGait/releases/download/v1.1/pretrained_grew_gaitgl.zip
    # !unzip -n demo/checkpoints/gait_model/pretrained_grew_gaitgl.zip -d demo/checkpoints/gait_model/
print('GREW GaitGL exists:', GaitGL_CKPT.exists(), GaitGL_CKPT)

# ByteTrack checkpoint.
ByteTrack_CKPT = OPENGAIT / 'demo/checkpoints/bytetrack_model/bytetrack_x_mot17.pth.tar'
if not ByteTrack_CKPT.exists():
    # %cd $OPENGAIT/demo/checkpoints/bytetrack_model
    # !gdown --fuzzy https://drive.google.com/file/d/1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5/view -O bytetrack_x_mot17.pth.tar
print('ByteTrack exists:', ByteTrack_CKPT.exists(), ByteTrack_CKPT)

# Human segmentation model.
SEG_DEPLOY = OPENGAIT / 'demo/checkpoints/seg_model/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax/deploy.yaml'
if not SEG_DEPLOY.exists():
    # %cd $OPENGAIT/demo/checkpoints/seg_model
    # !wget -nc https://paddleseg.bj.bcebos.com/dygraph/pp_humanseg_v2/human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
    # !unzip -n human_pp_humansegv2_mobile_192x192_inference_model_with_softmax.zip
print('Segmentation deploy exists:', SEG_DEPLOY.exists(), SEG_DEPLOY)

# %cd $ROOT

# %% [markdown]
# ## Final 3. Prepare Clean Demo Videos From Google Drive
#
# Gallery folder:
# `https://drive.google.com/drive/folders/19OQwGdyLc-QuAh5JqzLEg58uK7XnGFwH?usp=drive_link`
#
# Probe folder:
# `https://drive.google.com/drive/folders/1qSraegJ3hF_RjnIf4Gn1nwZ-2GPoJHIZ?usp=drive_link`
#
# By default:
# - first gallery video after sorting -> `pritomgallery.mp4`
# - second gallery video after sorting -> `cocogallery.mp4`
# - first probe video after sorting -> `test1probe.mp4`
#
# If the printed order is wrong, change the indices in this cell.

# %%
from pathlib import Path
import shutil

clean = ROOT / 'clean_demo_v2'
raw_gallery = clean / 'raw_gallery_drive'
raw_probe = clean / 'raw_probe_drive'

(clean / 'gallery').mkdir(parents=True, exist_ok=True)
(clean / 'probes').mkdir(parents=True, exist_ok=True)
raw_gallery.mkdir(parents=True, exist_ok=True)
raw_probe.mkdir(parents=True, exist_ok=True)

GALLERY_URL = 'https://drive.google.com/drive/folders/19OQwGdyLc-QuAh5JqzLEg58uK7XnGFwH?usp=drive_link'
PROBE_URL = 'https://drive.google.com/drive/folders/1qSraegJ3hF_RjnIf4Gn1nwZ-2GPoJHIZ?usp=drive_link'

# !gdown --folder "$GALLERY_URL" -O "$raw_gallery" --remaining-ok
# !gdown --folder "$PROBE_URL" -O "$raw_probe" --remaining-ok

video_exts = {'.mp4', '.avi', '.mov', '.mkv'}
gallery_videos = sorted([p for p in raw_gallery.rglob('*') if p.suffix.lower() in video_exts])
probe_videos = sorted([p for p in raw_probe.rglob('*') if p.suffix.lower() in video_exts])

print('Downloaded gallery videos:')
for i, p in enumerate(gallery_videos):
    print(i, p)
print('\nDownloaded probe videos:')
for i, p in enumerate(probe_videos):
    print(i, p)

if len(gallery_videos) < 2:
    raise RuntimeError('Need at least two gallery videos for closed-set mode.')
if len(probe_videos) < 1:
    raise RuntimeError('Need at least one probe video.')

# Change these indices if the printed order is not Pritom/Coco/Test1.
pritom_src = gallery_videos[0]
coco_src = gallery_videos[1]
probe_src = probe_videos[0]

shutil.copy(pritom_src, clean / 'gallery' / 'pritomgallery.mp4')
shutil.copy(coco_src, clean / 'gallery' / 'cocogallery.mp4')
shutil.copy(probe_src, clean / 'probes' / 'test1probe.mp4')

print('\nPrepared clean demo files:')
for p in [clean/'gallery/pritomgallery.mp4', clean/'gallery/cocogallery.mp4', clean/'probes/test1probe.mp4']:
    print(p, 'exists=', p.exists(), 'bytes=', p.stat().st_size if p.exists() else None)

# %% [markdown]
# ## Final 3B. Write Final Demo Scripts
#
# This cell writes the final clean-demo Python tools and shell scripts into `clean_demo_v2/` inside Colab. This is required because these generated project scripts are not part of the original upstream notebook by default.

# %%
from pathlib import Path
import os

ROOT = Path('/content/All-in-One-Gait') if Path('/content/All-in-One-Gait').exists() else Path('/home/ppaul11/All-in-One-Gait')
os.chdir(ROOT)
print('Writing final demo scripts under', ROOT / 'clean_demo_v2')

path = ROOT / 'clean_demo_v2/tools/build_two_identity_gallery.py'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('import argparse\nimport json\nimport sys\nfrom pathlib import Path\n\nimport numpy as np\n\nSCRIPT_DIR = Path(__file__).resolve().parent\nPROJECT_ROOT = SCRIPT_DIR.parents[1]\nsys.path.insert(0, str(PROJECT_ROOT / "OpenGait" / "tools"))\n\nfrom probe_only_entry_analysis import analyze_video, build_model, log  # noqa: E402\n\n\ndef process_gallery_video(model, video_path: Path, label: str, work_root: Path, min_frames: int):\n    entries = analyze_video(\n        model=model,\n        video_path=video_path,\n        work_root=work_root / label,\n        min_frames=min_frames,\n    )\n    ok_entries = [entry for entry in entries if entry["status"] == "ok"]\n    if not ok_entries:\n        raise ValueError(f"No valid gallery entries were extracted for {label}: {video_path}")\n    embeddings = np.stack([entry["embedding"].astype(np.float32) for entry in ok_entries], axis=0)\n    prototype = embeddings.mean(axis=0)\n    metadata = {\n        "label": label,\n        "video": str(video_path),\n        "valid_entries": len(ok_entries),\n        "entries": [\n            {\n                "entry_key": entry["entry_key"],\n                "track_id": entry["track_id"],\n                "frame_count": entry["frame_count"],\n                "embedding_norm": float(np.linalg.norm(entry["embedding"])),\n            }\n            for entry in ok_entries\n        ],\n    }\n    return prototype, metadata\n\n\ndef main():\n    parser = argparse.ArgumentParser(\n        description="Build a two-person Pritom/Coco gallery from clean_demo_v2 gallery videos."\n    )\n    parser.add_argument("--pritom-video", required=True)\n    parser.add_argument("--coco-video", required=True)\n    parser.add_argument("--gallery-out", required=True)\n    parser.add_argument("--metadata-out", required=True)\n    parser.add_argument("--work-root", required=True)\n    parser.add_argument("--model", choices=["grew_gaitbase", "current_gaitbase", "grew_gaitgl"], default="grew_gaitbase")\n    parser.add_argument("--min-frames", type=int, default=20)\n    args = parser.parse_args()\n\n    pritom_video = Path(args.pritom_video).resolve()\n    coco_video = Path(args.coco_video).resolve()\n    gallery_out = Path(args.gallery_out).resolve()\n    metadata_out = Path(args.metadata_out).resolve()\n    work_root = Path(args.work_root).resolve()\n\n    model, profile = build_model(args.model)\n    pritom_embedding, pritom_meta = process_gallery_video(model, pritom_video, "pritom", work_root, args.min_frames)\n    coco_embedding, coco_meta = process_gallery_video(model, coco_video, "coco", work_root, args.min_frames)\n\n    embeddings = np.stack([pritom_embedding, coco_embedding], axis=0).astype(np.float32)\n    labels = np.array(["pritom", "coco"])\n    entry_keys = np.array(["pritomgallery:gallery", "cocogallery:gallery"])\n    video_names = np.array([pritom_video.stem, coco_video.stem])\n\n    gallery_out.parent.mkdir(parents=True, exist_ok=True)\n    np.savez_compressed(\n        gallery_out,\n        embeddings=embeddings,\n        labels=labels,\n        entry_keys=entry_keys,\n        video_names=video_names,\n    )\n\n    pritom_flat = pritom_embedding.reshape(-1)\n    coco_flat = coco_embedding.reshape(-1)\n    cosine = float(np.dot(pritom_flat, coco_flat) / (np.linalg.norm(pritom_flat) * np.linalg.norm(coco_flat)))\n    metadata = {\n        "model": profile["display_name"],\n        "model_key": args.model,\n        "gallery_out": str(gallery_out),\n        "identities": {\n            "pritom": pritom_meta,\n            "coco": coco_meta,\n        },\n        "pritom_vs_coco_cosine": cosine,\n    }\n    metadata_out.parent.mkdir(parents=True, exist_ok=True)\n    metadata_out.write_text(json.dumps(metadata, indent=2))\n    log(json.dumps({"gallery_out": str(gallery_out), "pritom_vs_coco_cosine": cosine}, indent=2))\n\n\nif __name__ == "__main__":\n    main()\n')
print('wrote', path)

path = ROOT / 'clean_demo_v2/tools/identify_probe_with_gallery.py'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('import argparse\nimport json\nfrom collections import Counter\nfrom pathlib import Path\nimport sys\nfrom typing import Dict, List\n\nimport numpy as np\n\nSCRIPT_DIR = Path(__file__).resolve().parent\nPROJECT_ROOT = SCRIPT_DIR.parents[1]\nsys.path.insert(0, str(PROJECT_ROOT / "OpenGait" / "tools"))\n\nfrom probe_only_entry_analysis import (\n    PROJECT_ROOT,\n    REPO_ROOT,\n    analyze_video,\n    build_model,\n    cosine_similarity,\n    log,\n)\n\n\ndef load_gallery(path: Path) -> Dict:\n    data = np.load(path)\n    return {\n        "embeddings": data["embeddings"].astype(np.float32),\n        "labels": data["labels"].astype(str),\n        "entry_keys": data["entry_keys"].astype(str),\n        "video_names": data["video_names"].astype(str),\n    }\n\n\ndef score_identity(probe_embedding: np.ndarray, gallery_embeddings: np.ndarray, mode: str, top_k: int) -> float:\n    scores = np.array([cosine_similarity(probe_embedding, emb) for emb in gallery_embeddings], dtype=np.float32)\n    if scores.size == 0:\n        return -1.0\n    if mode == "max":\n        return float(np.max(scores))\n    if mode == "mean":\n        return float(np.mean(scores))\n    if mode == "topk":\n        k = min(top_k, scores.size)\n        return float(np.mean(np.sort(scores)[-k:]))\n    raise ValueError(f"Unsupported match mode: {mode}")\n\n\ndef identify_entry(\n    embedding: np.ndarray,\n    gallery: Dict,\n    match_mode: str,\n    top_k: int,\n    threshold: float,\n    margin: float,\n) -> Dict:\n    identity_scores = {}\n    for identity in sorted(set(gallery["labels"])):\n        mask = gallery["labels"] == identity\n        identity_scores[identity] = score_identity(\n            embedding,\n            gallery["embeddings"][mask],\n            mode=match_mode,\n            top_k=top_k,\n        )\n\n    ranked = sorted(identity_scores.items(), key=lambda item: item[1], reverse=True)\n    best_identity, best_score = ranked[0]\n    second_identity, second_score = ranked[1] if len(ranked) > 1 else ("none", -1.0)\n    score_margin = best_score - second_score\n    accepted = best_score >= threshold and score_margin >= margin\n\n    return {\n        "assigned_identity": best_identity if accepted else "unknown",\n        "accepted": accepted,\n        "best_identity": best_identity,\n        "best_score": float(best_score),\n        "second_identity": second_identity,\n        "second_score": float(second_score),\n        "score_margin": float(score_margin),\n        "identity_scores": {key: float(value) for key, value in identity_scores.items()},\n    }\n\n\ndef main():\n    parser = argparse.ArgumentParser(\n        description="Identify entries in probe videos using a multi-identity gait gallery."\n    )\n    parser.add_argument("--gallery-npz", default=str(REPO_ROOT / "output" / "multi_identity_gallery.npz"))\n    parser.add_argument("--video-dir", default=str(PROJECT_ROOT / "newvideos"))\n    parser.add_argument("--video-path", default=None, help="Optional single probe video. Defaults to Test1/Test2.")\n    parser.add_argument("--output-json", default=str(REPO_ROOT / "output" / "multi_gallery_probe_results.json"))\n    parser.add_argument("--work-root", default=str(REPO_ROOT / "demo" / "output" / "multi_gallery_probe"))\n    parser.add_argument("--model", choices=["grew_gaitbase", "current_gaitbase", "grew_gaitgl"], default="grew_gaitbase")\n    parser.add_argument("--min-frames", type=int, default=20)\n    parser.add_argument("--threshold", type=float, default=0.97)\n    parser.add_argument("--margin", type=float, default=0.005)\n    parser.add_argument("--match-mode", choices=["max", "mean", "topk"], default="max")\n    parser.add_argument("--top-k", type=int, default=3)\n    args = parser.parse_args()\n\n    gallery_path = Path(args.gallery_npz).resolve()\n    video_dir = Path(args.video_dir).resolve()\n    output_json = Path(args.output_json).resolve()\n    work_root = Path(args.work_root).resolve()\n\n    if not gallery_path.exists():\n        raise FileNotFoundError(f"Gallery file does not exist: {gallery_path}")\n\n    if args.video_path:\n        video_paths = [Path(args.video_path).resolve()]\n    else:\n        video_paths = [video_dir / "Test1.mp4", video_dir / "Test2.mp4"]\n        missing = [path for path in video_paths if not path.exists()]\n        if missing:\n            raise FileNotFoundError("Missing probe videos: " + ", ".join(str(path) for path in missing))\n\n    gallery = load_gallery(gallery_path)\n    model, profile = build_model(args.model)\n\n    all_entries: List[Dict] = []\n    for video_path in video_paths:\n        log(f"[probe] analyzing {video_path.name}")\n        all_entries.extend(\n            analyze_video(\n                model=model,\n                video_path=video_path,\n                work_root=work_root,\n                min_frames=args.min_frames,\n            )\n        )\n\n    resolved_entries = []\n    for entry in all_entries:\n        item = {\n            "entry_key": entry["entry_key"],\n            "video": entry["video"],\n            "track_id": entry["track_id"],\n            "sequence_name": entry["sequence_name"],\n            "frame_count": entry["frame_count"],\n            "status": entry["status"],\n        }\n        if entry["status"] == "ok":\n            item.update(\n                identify_entry(\n                    entry["embedding"],\n                    gallery=gallery,\n                    match_mode=args.match_mode,\n                    top_k=args.top_k,\n                    threshold=args.threshold,\n                    margin=args.margin,\n                )\n            )\n        resolved_entries.append(item)\n\n    counts = Counter(\n        entry["assigned_identity"]\n        for entry in resolved_entries\n        if entry["status"] == "ok"\n    )\n    per_video_counts = {}\n    for entry in resolved_entries:\n        if entry["status"] != "ok":\n            continue\n        per_video_counts.setdefault(entry["video"], Counter())\n        per_video_counts[entry["video"]][entry["assigned_identity"]] += 1\n\n    results = {\n        "config": {\n            "gallery_npz": str(gallery_path),\n            "video_paths": [str(path) for path in video_paths],\n            "work_root": str(work_root),\n            "output_json": str(output_json),\n            "model": profile["display_name"],\n            "model_key": args.model,\n            "threshold": args.threshold,\n            "margin": args.margin,\n            "match_mode": args.match_mode,\n            "top_k": args.top_k,\n            "gallery_identities": sorted(set(gallery["labels"])),\n        },\n        "summary": {\n            "processed_entries": sum(1 for entry in resolved_entries if entry["status"] == "ok"),\n            "skipped_entries": sum(1 for entry in resolved_entries if entry["status"] != "ok"),\n            "counts": dict(counts),\n            "per_video_counts": {video: dict(counter) for video, counter in per_video_counts.items()},\n        },\n        "entries": resolved_entries,\n    }\n\n    output_json.parent.mkdir(parents=True, exist_ok=True)\n    output_json.write_text(json.dumps(results, indent=2))\n    log(json.dumps(results["summary"], indent=2))\n    log(f"[probe] saved multi-gallery probe results to {output_json}")\n\n\nif __name__ == "__main__":\n    main()\n')
print('wrote', path)

path = ROOT / 'clean_demo_v2/tools/render_closed_set_annotations.py'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('import argparse\nimport json\nfrom collections import Counter\nfrom pathlib import Path\nfrom typing import Dict, List\n\nimport cv2\n\n\ndef load_tracking_file(path: Path) -> Dict[int, List[Dict]]:\n    frame_tracks: Dict[int, List[Dict]] = {}\n    for line in path.read_text().splitlines():\n        parts = line.split(",")\n        if len(parts) < 6:\n            continue\n        frame_id = int(float(parts[0]))\n        track_id = int(float(parts[1]))\n        frame_tracks.setdefault(frame_id, []).append(\n            {\n                "track_id": f"{track_id:03d}",\n                "bbox": [float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5])],\n            }\n        )\n    return frame_tracks\n\n\ndef color_for_label(label: str):\n    colors = {\n        "pritom": (0, 220, 0),\n        "coco": (255, 140, 0),\n        "jeevith": (0, 165, 255),\n        "unknown": (180, 180, 180),\n    }\n    return colors.get(label, (255, 255, 255))\n\n\ndef draw_label(frame, x: int, y: int, text: str, color):\n    font = cv2.FONT_HERSHEY_SIMPLEX\n    scale = 0.72\n    thickness = 2\n    (tw, th), baseline = cv2.getTextSize(text, font, scale, thickness)\n    y0 = max(0, y - th - baseline - 8)\n    cv2.rectangle(frame, (x, y0), (x + tw + 8, y0 + th + baseline + 8), color, -1)\n    cv2.putText(frame, text, (x + 4, y0 + th + 2), font, scale, (0, 0, 0), thickness, cv2.LINE_AA)\n\n\ndef build_decisions(result_json: Path) -> Dict[str, Dict]:\n    payload = json.loads(result_json.read_text())\n    counts = Counter()\n    decisions = {}\n    for entry in sorted(payload["entries"], key=lambda item: item["track_id"]):\n        if entry["status"] != "ok":\n            continue\n        label = entry["assigned_identity"]\n        counts[label] += 1\n        decisions[entry["track_id"]] = {\n            "label": label,\n            "count": counts[label],\n            "score": entry["best_score"],\n            "second_identity": entry["second_identity"],\n            "second_score": entry["second_score"],\n        }\n    return decisions\n\n\ndef main():\n    parser = argparse.ArgumentParser(\n        description="Render a closed-set annotated video from an existing result JSON and tracking TXT."\n    )\n    parser.add_argument("--video-path", required=True)\n    parser.add_argument("--tracking-txt", required=True)\n    parser.add_argument("--result-json", required=True)\n    parser.add_argument("--output-video", required=True)\n    parser.add_argument("--title", default="Closed-set gait recognition")\n    args = parser.parse_args()\n\n    video_path = Path(args.video_path).resolve()\n    tracking_txt = Path(args.tracking_txt).resolve()\n    result_json = Path(args.result_json).resolve()\n    output_video = Path(args.output_video).resolve()\n\n    frame_tracks = load_tracking_file(tracking_txt)\n    decisions = build_decisions(result_json)\n\n    cap = cv2.VideoCapture(str(video_path))\n    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0\n    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))\n    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))\n    output_video.parent.mkdir(parents=True, exist_ok=True)\n    writer = cv2.VideoWriter(str(output_video), cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height))\n\n    frame_id = 0\n    while True:\n        ok, frame = cap.read()\n        if not ok:\n            break\n        cv2.putText(frame, args.title, (25, 45), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 3, cv2.LINE_AA)\n        for item in frame_tracks.get(frame_id, []):\n            decision = decisions.get(item["track_id"])\n            if decision is None:\n                continue\n            x, y, w, h = item["bbox"]\n            x1, y1 = int(x), int(y)\n            x2, y2 = int(x + w), int(y + h)\n            color = color_for_label(decision["label"])\n            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)\n            text = f"{decision[\'label\']} count={decision[\'count\']} score={decision[\'score\']:.3f}"\n            draw_label(frame, x1, max(0, y1 - 4), text, color)\n        writer.write(frame)\n        frame_id += 1\n\n    cap.release()\n    writer.release()\n    print(f"[render] saved annotated video to {output_video}", flush=True)\n\n\nif __name__ == "__main__":\n    main()\n')
print('wrote', path)

path = ROOT / 'clean_demo_v2/run_pritom_coco_test1_closed.sh'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('#!/usr/bin/env bash\nset -euo pipefail\n\nROOT="/home/ppaul11/All-in-One-Gait"\ncd "$ROOT"\n\nTS="$(date +%Y%m%d_%H%M%S)"\nCLEAN_ROOT="$ROOT/clean_demo_v2"\nOUT_ROOT="$CLEAN_ROOT/output/pritom_coco_test1_closed_$TS"\nWORK_ROOT="$OUT_ROOT/work"\n\nMODEL="${MODEL:-grew_gaitbase}"\n\nmkdir -p "$OUT_ROOT"\n\necho "[pritom-coco-closed] timestamp=$TS"\necho "[pritom-coco-closed] model=$MODEL"\necho "[pritom-coco-closed] gallery pritom: $CLEAN_ROOT/gallery/pritomgallery.mp4"\necho "[pritom-coco-closed] gallery coco:   $CLEAN_ROOT/gallery/cocogallery.mp4"\necho "[pritom-coco-closed] probe:          $CLEAN_ROOT/probes/test1probe.mp4"\n\npython clean_demo_v2/tools/build_two_identity_gallery.py \\\n  --pritom-video "$CLEAN_ROOT/gallery/pritomgallery.mp4" \\\n  --coco-video "$CLEAN_ROOT/gallery/cocogallery.mp4" \\\n  --model "$MODEL" \\\n  --work-root "$WORK_ROOT/gallery_build" \\\n  --gallery-out "$OUT_ROOT/pritom_coco_gallery.npz" \\\n  --metadata-out "$OUT_ROOT/pritom_coco_gallery.json"\n\npython clean_demo_v2/tools/identify_probe_with_gallery.py \\\n  --gallery-npz "$OUT_ROOT/pritom_coco_gallery.npz" \\\n  --video-path "$CLEAN_ROOT/probes/test1probe.mp4" \\\n  --model "$MODEL" \\\n  --threshold -1 \\\n  --margin 0 \\\n  --match-mode max \\\n  --work-root "$WORK_ROOT/probe_test1" \\\n  --output-json "$OUT_ROOT/test1_pritom_coco_closed_result.json"\n\npython - "$OUT_ROOT" <<\'PY\'\nimport json\nimport sys\nfrom pathlib import Path\n\nout_root = Path(sys.argv[1])\nresult_path = out_root / "test1_pritom_coco_closed_result.json"\npayload = json.loads(result_path.read_text())\nsummary_path = out_root / "test1_pritom_coco_closed_summary.txt"\nlines = [\n    "Pritom/Coco closed-set Test1 summary",\n    f"Counts: {payload[\'summary\'][\'counts\']}",\n    f"Processed entries: {payload[\'summary\'][\'processed_entries\']}",\n    f"Skipped entries: {payload[\'summary\'][\'skipped_entries\']}",\n    "",\n    "Per-entry assignments:",\n]\nfor entry in payload["entries"]:\n    if entry["status"] != "ok":\n        lines.append(f"{entry[\'entry_key\']}: skipped {entry[\'status\']}")\n        continue\n    lines.append(\n        f"{entry[\'entry_key\']}: {entry[\'assigned_identity\']} "\n        f"best={entry[\'best_score\']:.4f} second={entry[\'second_identity\']}:{entry[\'second_score\']:.4f}"\n    )\nsummary_path.write_text("\\n".join(lines))\nprint(json.dumps(payload["summary"], indent=2))\nprint(f"[pritom-coco-closed] saved summary: {summary_path}")\nPY\n\npython clean_demo_v2/tools/render_closed_set_annotations.py \\\n  --video-path "$CLEAN_ROOT/probes/test1probe.mp4" \\\n  --tracking-txt "$WORK_ROOT/probe_test1/tracking/test1probe/test1probe.txt" \\\n  --result-json "$OUT_ROOT/test1_pritom_coco_closed_result.json" \\\n  --output-video "$OUT_ROOT/test1_pritom_coco_closed_annotated.mp4" \\\n  --title "Pritom vs Coco closed-set"\n\necho "[pritom-coco-closed] finished"\necho "[pritom-coco-closed] output folder: $OUT_ROOT"\necho "[pritom-coco-closed] result JSON: $OUT_ROOT/test1_pritom_coco_closed_result.json"\necho "[pritom-coco-closed] annotated video: $OUT_ROOT/test1_pritom_coco_closed_annotated.mp4"\n')
path.chmod(0o755)
print('wrote', path)

path = ROOT / 'clean_demo_v2/tools/build_single_target_gallery.py'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('import argparse\nimport json\nimport sys\nfrom pathlib import Path\n\nimport numpy as np\n\nSCRIPT_DIR = Path(__file__).resolve().parent\nPROJECT_ROOT = SCRIPT_DIR.parents[1]\nsys.path.insert(0, str(PROJECT_ROOT / "OpenGait" / "tools"))\n\nfrom probe_only_entry_analysis import analyze_video, build_model, log  # noqa: E402\n\n\ndef main():\n    parser = argparse.ArgumentParser(\n        description="Build a single-person target gallery from one gallery video."\n    )\n    parser.add_argument("--gallery-video", required=True)\n    parser.add_argument("--target-label", default="pritom")\n    parser.add_argument("--gallery-out", required=True)\n    parser.add_argument("--metadata-out", required=True)\n    parser.add_argument("--work-root", required=True)\n    parser.add_argument("--model", choices=["grew_gaitbase", "current_gaitbase", "grew_gaitgl"], default="grew_gaitbase")\n    parser.add_argument("--min-frames", type=int, default=20)\n    args = parser.parse_args()\n\n    gallery_video = Path(args.gallery_video).resolve()\n    gallery_out = Path(args.gallery_out).resolve()\n    metadata_out = Path(args.metadata_out).resolve()\n    work_root = Path(args.work_root).resolve()\n\n    if not gallery_video.exists():\n        raise FileNotFoundError(f"Gallery video does not exist: {gallery_video}")\n\n    model, profile = build_model(args.model)\n    entries = analyze_video(\n        model=model,\n        video_path=gallery_video,\n        work_root=work_root,\n        min_frames=args.min_frames,\n    )\n    ok_entries = [entry for entry in entries if entry["status"] == "ok"]\n    if not ok_entries:\n        raise ValueError("No valid gallery entries were extracted.")\n\n    embeddings = np.stack([entry["embedding"].astype(np.float32) for entry in ok_entries], axis=0)\n    labels = np.array([args.target_label] * embeddings.shape[0])\n    entry_keys = np.array([entry["entry_key"] for entry in ok_entries])\n    video_names = np.array([entry["video"] for entry in ok_entries])\n\n    gallery_out.parent.mkdir(parents=True, exist_ok=True)\n    np.savez_compressed(\n        gallery_out,\n        embeddings=embeddings,\n        labels=labels,\n        entry_keys=entry_keys,\n        video_names=video_names,\n    )\n\n    metadata = {\n        "target_label": args.target_label,\n        "gallery_video": str(gallery_video),\n        "gallery_out": str(gallery_out),\n        "model": profile["display_name"],\n        "model_key": args.model,\n        "valid_gallery_entries": len(ok_entries),\n        "entries": [\n            {\n                "entry_key": entry["entry_key"],\n                "video": entry["video"],\n                "track_id": entry["track_id"],\n                "frame_count": entry["frame_count"],\n                "embedding_norm": float(np.linalg.norm(entry["embedding"])),\n            }\n            for entry in ok_entries\n        ],\n    }\n    metadata_out.parent.mkdir(parents=True, exist_ok=True)\n    metadata_out.write_text(json.dumps(metadata, indent=2))\n    log(json.dumps({"valid_gallery_entries": len(ok_entries), "gallery_out": str(gallery_out)}, indent=2))\n\n\nif __name__ == "__main__":\n    main()\n')
print('wrote', path)

path = ROOT / 'clean_demo_v2/tools/threshold_target_probe_with_video.py'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('import argparse\nimport json\nimport sys\nfrom collections import Counter\nfrom pathlib import Path\nfrom typing import Dict, List\n\nimport cv2\nimport numpy as np\n\nSCRIPT_DIR = Path(__file__).resolve().parent\nPROJECT_ROOT = SCRIPT_DIR.parents[1]\nsys.path.insert(0, str(PROJECT_ROOT / "OpenGait" / "tools"))\n\nfrom probe_only_entry_analysis import analyze_video, build_model, cosine_similarity, log  # noqa: E402\n\n\ndef load_gallery(path: Path):\n    data = np.load(path)\n    return data["embeddings"].astype(np.float32), data["labels"].astype(str)\n\n\ndef score_to_gallery(embedding: np.ndarray, gallery_embeddings: np.ndarray) -> float:\n    return float(max(cosine_similarity(embedding, gallery_embedding) for gallery_embedding in gallery_embeddings))\n\n\ndef load_tracking_file(path: Path) -> Dict[int, List[Dict]]:\n    frame_tracks: Dict[int, List[Dict]] = {}\n    for line in path.read_text().splitlines():\n        parts = line.split(",")\n        if len(parts) < 6:\n            continue\n        frame_id = int(float(parts[0]))\n        track_id = int(float(parts[1]))\n        frame_tracks.setdefault(frame_id, []).append(\n            {\n                "track_id": f"{track_id:03d}",\n                "bbox": [float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5])],\n            }\n        )\n    return frame_tracks\n\n\ndef draw_label(frame, x: int, y: int, text: str, color):\n    font = cv2.FONT_HERSHEY_SIMPLEX\n    scale = 0.72\n    thickness = 2\n    (tw, th), baseline = cv2.getTextSize(text, font, scale, thickness)\n    y0 = max(0, y - th - baseline - 8)\n    cv2.rectangle(frame, (x, y0), (x + tw + 8, y0 + th + baseline + 8), color, -1)\n    cv2.putText(frame, text, (x + 4, y0 + th + 2), font, scale, (0, 0, 0), thickness, cv2.LINE_AA)\n\n\ndef render(video_path: Path, tracking_txt: Path, decisions: List[Dict], output_video: Path, threshold: float):\n    decision_by_track = {item["track_id"]: item for item in decisions}\n    frame_tracks = load_tracking_file(tracking_txt)\n    cap = cv2.VideoCapture(str(video_path))\n    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0\n    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))\n    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))\n    output_video.parent.mkdir(parents=True, exist_ok=True)\n    writer = cv2.VideoWriter(str(output_video), cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height))\n\n    frame_id = 0\n    while True:\n        ok, frame = cap.read()\n        if not ok:\n            break\n\n        cv2.putText(\n            frame,\n            f"Pritom vs Unknown | threshold={threshold}",\n            (25, 45),\n            cv2.FONT_HERSHEY_SIMPLEX,\n            1.0,\n            (255, 255, 255),\n            3,\n            cv2.LINE_AA,\n        )\n        for item in frame_tracks.get(frame_id, []):\n            decision = decision_by_track.get(item["track_id"])\n            if decision is None:\n                continue\n            x, y, w, h = item["bbox"]\n            x1, y1 = int(x), int(y)\n            x2, y2 = int(x + w), int(y + h)\n            label = decision["assigned_label"]\n            color = (0, 220, 0) if label == "pritom" else (0, 165, 255)\n            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)\n            text = f"{label} count={decision[\'display_count\']} score={decision[\'score_to_target\']:.3f}"\n            draw_label(frame, x1, max(0, y1 - 4), text, color)\n\n        writer.write(frame)\n        frame_id += 1\n\n    cap.release()\n    writer.release()\n\n\ndef main():\n    parser = argparse.ArgumentParser(\n        description="Threshold one target gallery against one probe and render readable labels."\n    )\n    parser.add_argument("--gallery-npz", required=True)\n    parser.add_argument("--probe-video", required=True)\n    parser.add_argument("--target-label", default="pritom")\n    parser.add_argument("--threshold", type=float, default=0.97)\n    parser.add_argument("--output-json", required=True)\n    parser.add_argument("--summary-txt", required=True)\n    parser.add_argument("--output-video", required=True)\n    parser.add_argument("--work-root", required=True)\n    parser.add_argument("--model", choices=["grew_gaitbase", "current_gaitbase", "grew_gaitgl"], default="grew_gaitbase")\n    parser.add_argument("--min-frames", type=int, default=20)\n    args = parser.parse_args()\n\n    gallery_npz = Path(args.gallery_npz).resolve()\n    probe_video = Path(args.probe_video).resolve()\n    output_json = Path(args.output_json).resolve()\n    summary_txt = Path(args.summary_txt).resolve()\n    output_video = Path(args.output_video).resolve()\n    work_root = Path(args.work_root).resolve()\n\n    gallery_embeddings, labels = load_gallery(gallery_npz)\n    target_embeddings = gallery_embeddings[labels == args.target_label]\n    if target_embeddings.shape[0] == 0:\n        raise ValueError(f"No embeddings found for target label {args.target_label}")\n\n    model, profile = build_model(args.model)\n    entries = analyze_video(model=model, video_path=probe_video, work_root=work_root, min_frames=args.min_frames)\n\n    counts = Counter()\n    decisions = []\n    skipped = []\n    for entry in sorted(entries, key=lambda item: item["track_id"]):\n        if entry["status"] != "ok":\n            skipped.append(\n                {\n                    "entry_key": entry["entry_key"],\n                    "track_id": entry["track_id"],\n                    "frame_count": entry["frame_count"],\n                    "status": entry["status"],\n                }\n            )\n            continue\n        score = score_to_gallery(entry["embedding"], target_embeddings)\n        assigned = args.target_label if score >= args.threshold else "unknown"\n        counts[assigned] += 1\n        decisions.append(\n            {\n                "entry_key": entry["entry_key"],\n                "video": entry["video"],\n                "track_id": entry["track_id"],\n                "frame_count": entry["frame_count"],\n                "score_to_target": score,\n                "assigned_label": assigned,\n                "display_count": counts[assigned],\n            }\n        )\n\n    tracking_txt = work_root / "tracking" / probe_video.stem / f"{probe_video.stem}.txt"\n    render(probe_video, tracking_txt, decisions, output_video, args.threshold)\n\n    payload = {\n        "config": {\n            "gallery_npz": str(gallery_npz),\n            "probe_video": str(probe_video),\n            "target_label": args.target_label,\n            "threshold": args.threshold,\n            "model": profile["display_name"],\n            "model_key": args.model,\n            "output_video": str(output_video),\n        },\n        "summary": {\n            "processed_entries": len(decisions),\n            "skipped_entries": len(skipped),\n            "counts": dict(counts),\n        },\n        "entries": decisions,\n        "skipped_entries": skipped,\n    }\n    output_json.parent.mkdir(parents=True, exist_ok=True)\n    output_json.write_text(json.dumps(payload, indent=2))\n    summary_txt.parent.mkdir(parents=True, exist_ok=True)\n    summary_txt.write_text(\n        "\\n".join(\n            [\n                "Clean Demo V2: Pritom vs Unknown",\n                f"Probe: {probe_video}",\n                f"Threshold: {args.threshold}",\n                f"Counts: {dict(counts)}",\n                f"Processed entries: {len(decisions)}",\n                f"Skipped entries: {len(skipped)}",\n                f"Output video: {output_video}",\n            ]\n        )\n    )\n    log(json.dumps(payload["summary"], indent=2))\n    log(f"[v2] saved JSON to {output_json}")\n    log(f"[v2] saved summary to {summary_txt}")\n    log(f"[v2] saved annotated video to {output_video}")\n\n\nif __name__ == "__main__":\n    main()\n')
print('wrote', path)

path = ROOT / 'clean_demo_v2/run_test1_threshold.sh'
path.parent.mkdir(parents=True, exist_ok=True)
path.write_text('#!/usr/bin/env bash\nset -euo pipefail\n\nROOT="/home/ppaul11/All-in-One-Gait"\ncd "$ROOT"\n\nTS="$(date +%Y%m%d_%H%M%S)"\nCLEAN_ROOT="$ROOT/clean_demo_v2"\nOUT_ROOT="$CLEAN_ROOT/output/pritom_test1_threshold_$TS"\nWORK_ROOT="$OUT_ROOT/work"\n\nMODEL="${MODEL:-grew_gaitbase}"\nTHRESHOLD="${THRESHOLD:-0.97}"\n\nmkdir -p "$OUT_ROOT"\n\necho "[clean-demo-v2] timestamp=$TS"\necho "[clean-demo-v2] model=$MODEL threshold=$THRESHOLD"\necho "[clean-demo-v2] gallery: $CLEAN_ROOT/gallery/pritomgallery.mp4"\necho "[clean-demo-v2] probe:   $CLEAN_ROOT/probes/test1probe.mp4"\n\npython clean_demo_v2/tools/build_single_target_gallery.py \\\n  --gallery-video "$CLEAN_ROOT/gallery/pritomgallery.mp4" \\\n  --target-label pritom \\\n  --model "$MODEL" \\\n  --work-root "$WORK_ROOT/gallery_build" \\\n  --gallery-out "$OUT_ROOT/pritom_gallery.npz" \\\n  --metadata-out "$OUT_ROOT/pritom_gallery.json"\n\npython clean_demo_v2/tools/threshold_target_probe_with_video.py \\\n  --gallery-npz "$OUT_ROOT/pritom_gallery.npz" \\\n  --probe-video "$CLEAN_ROOT/probes/test1probe.mp4" \\\n  --target-label pritom \\\n  --threshold "$THRESHOLD" \\\n  --model "$MODEL" \\\n  --work-root "$WORK_ROOT/probe_test1" \\\n  --output-json "$OUT_ROOT/test1_pritom_vs_unknown.json" \\\n  --summary-txt "$OUT_ROOT/test1_pritom_vs_unknown.txt" \\\n  --output-video "$OUT_ROOT/test1_pritom_vs_unknown_annotated.mp4"\n\necho "[clean-demo-v2] finished"\necho "[clean-demo-v2] output folder: $OUT_ROOT"\necho "[clean-demo-v2] result JSON: $OUT_ROOT/test1_pritom_vs_unknown.json"\necho "[clean-demo-v2] summary TXT: $OUT_ROOT/test1_pritom_vs_unknown.txt"\necho "[clean-demo-v2] annotated video: $OUT_ROOT/test1_pritom_vs_unknown_annotated.mp4"\n')
path.chmod(0o755)
print('wrote', path)

# %% [markdown]
# ## Final 4. Run Closed-Set Gallery/Probe Recognition
#
# This uses the final shell script. It builds a Pritom/Coco gallery, runs Test1 as probe, and renders an annotated video by default.
#
# To compare models, change `MODEL=grew_gaitbase` to `MODEL=grew_gaitgl`.

# %%
# %cd /content/All-in-One-Gait
# !MODEL=grew_gaitbase bash clean_demo_v2/run_pritom_coco_test1_closed.sh

# %% [markdown]
# ## Final 5. Inspect Latest Output

# %%
import json
from pathlib import Path

out_root = ROOT / 'clean_demo_v2/output'
runs = sorted(out_root.glob('pritom_coco_test1_closed_*'))
latest = runs[-1]
print('Latest output:', latest)

result_path = latest / 'test1_pritom_coco_closed_result.json'
summary_path = latest / 'test1_pritom_coco_closed_summary.txt'
video_path = latest / 'test1_pritom_coco_closed_annotated.mp4'

result = json.loads(result_path.read_text())
print(json.dumps(result['summary'], indent=2))
print('\nSummary text:')
print(summary_path.read_text())
print('\nAnnotated video:', video_path)

# %% [markdown]
# ## Final 6. Display Annotated Video In Colab

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = video_path.read_bytes()
data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
HTML('<video width="720" controls><source src="{}" type="video/mp4"></video>'.format(data_url))

# %% [markdown]
# ## Final 7. Optional Gradio Deployment Interface
#
# This launches a temporary public Gradio link in Colab. The link is not permanent; it works only while the Colab runtime is alive.
#
# The app is generic:
# - upload any number of gallery videos,
# - upload one probe video,
# - gallery videos are automatically labeled `person1`, `person2`, `person3`, ... by upload order,
# - if 2+ gallery videos are uploaded, it runs closed-set best-match recognition,
# - if only 1 gallery video is uploaded, it falls back to `person1` vs `unknown` thresholding,
# - output includes counts plus an annotated overlay video.

# %% [markdown]
# ## Final 7A. Write Gradio App File
#
# This cell writes the latest generic deployment app into `clean_demo_v2/gradio_app.py` directly from the notebook. This keeps the Colab workflow self-contained, so you do not need to manually add or edit the Gradio app file.

# %%
from pathlib import Path

app_path = Path('/content/All-in-One-Gait/clean_demo_v2/gradio_app.py')
app_path.parent.mkdir(parents=True, exist_ok=True)
app_path.write_text('import json\nimport shutil\nimport subprocess\nimport sys\nimport time\nfrom collections import Counter\nfrom pathlib import Path\nfrom typing import Dict, List\n\nimport cv2\nimport gradio as gr\nimport numpy as np\n\n\nROOT = Path(__file__).resolve().parents[1]\nCLEAN_ROOT = ROOT / "clean_demo_v2"\nOPENGAIT_TOOLS = ROOT / "OpenGait" / "tools"\nsys.path.insert(0, str(OPENGAIT_TOOLS))\n\nfrom probe_only_entry_analysis import analyze_video, build_model, cosine_similarity, log  # noqa: E402\n\n\ndef copy_upload(src, dst: Path):\n    src_path = Path(src)\n    dst.parent.mkdir(parents=True, exist_ok=True)\n    shutil.copy(src_path, dst)\n    return dst\n\n\ndef timestamped_run_root() -> Path:\n    ts = time.strftime("%Y%m%d_%H%M%S")\n    run_root = CLEAN_ROOT / "output" / f"gradio_multi_gallery_{ts}"\n    run_root.mkdir(parents=True, exist_ok=True)\n    return run_root\n\n\ndef load_tracking_file(path: Path) -> Dict[int, List[Dict]]:\n    frame_tracks: Dict[int, List[Dict]] = {}\n    if not path.exists():\n        raise FileNotFoundError(f"Tracking file not found: {path}")\n    for line in path.read_text().splitlines():\n        parts = line.split(",")\n        if len(parts) < 6:\n            continue\n        frame_id = int(float(parts[0]))\n        track_id = int(float(parts[1]))\n        frame_tracks.setdefault(frame_id, []).append(\n            {\n                "track_id": f"{track_id:03d}",\n                "bbox": [float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5])],\n            }\n        )\n    return frame_tracks\n\n\ndef color_for_label(label: str):\n    if label == "unknown":\n        return (150, 150, 150)\n    try:\n        idx = int(label.replace("person", ""))\n    except ValueError:\n        idx = 1\n    return ((37 * idx) % 255, (137 * idx) % 255, (211 * idx) % 255)\n\n\ndef draw_label(frame, x: int, y: int, text: str, color):\n    font = cv2.FONT_HERSHEY_SIMPLEX\n    scale = 0.72\n    thickness = 2\n    (tw, th), baseline = cv2.getTextSize(text, font, scale, thickness)\n    y0 = max(0, y - th - baseline - 8)\n    cv2.rectangle(frame, (x, y0), (x + tw + 8, y0 + th + baseline + 8), color, -1)\n    cv2.putText(frame, text, (x + 4, y0 + th + 2), font, scale, (0, 0, 0), thickness, cv2.LINE_AA)\n\n\ndef clip_video(input_path: Path, output_path: Path, max_seconds: float) -> Path:\n    if max_seconds <= 0:\n        return input_path\n\n    cap = cv2.VideoCapture(str(input_path))\n    if not cap.isOpened():\n        raise RuntimeError(f"Could not open probe video for clipping: {input_path}")\n\n    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0\n    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))\n    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))\n    max_frames = int(max_seconds * fps)\n    output_path.parent.mkdir(parents=True, exist_ok=True)\n    writer = cv2.VideoWriter(str(output_path), cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height))\n\n    written = 0\n    while written < max_frames:\n        ok, frame = cap.read()\n        if not ok:\n            break\n        writer.write(frame)\n        written += 1\n\n    cap.release()\n    writer.release()\n    if written == 0:\n        raise RuntimeError("Probe clipping produced zero frames.")\n    return output_path\n\n\ndef render_annotations(\n    video_path: Path,\n    tracking_txt: Path,\n    decisions: List[Dict],\n    output_video: Path,\n    title: str,\n    max_side: int = 720,\n    target_fps: float = 24.0,\n):\n    decision_by_track = {item["track_id"]: item for item in decisions}\n    frame_tracks = load_tracking_file(tracking_txt)\n\n    cap = cv2.VideoCapture(str(video_path))\n    input_fps = cap.get(cv2.CAP_PROP_FPS) or 30.0\n    stride = max(1, int(round(input_fps / target_fps)))\n    fps = input_fps / stride\n    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))\n    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))\n    largest_side = max(width, height)\n    if largest_side > max_side:\n        scale = max_side / largest_side\n        out_width = int(width * scale)\n        out_height = int(height * scale)\n    else:\n        out_width = width\n        out_height = height\n    output_video.parent.mkdir(parents=True, exist_ok=True)\n    writer = cv2.VideoWriter(str(output_video), cv2.VideoWriter_fourcc(*"mp4v"), fps, (out_width, out_height))\n\n    frame_id = 0\n    written_frames = 0\n    while True:\n        ok, frame = cap.read()\n        if not ok:\n            break\n        if frame_id % stride != 0:\n            frame_id += 1\n            continue\n        cv2.putText(frame, title, (25, 45), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 3, cv2.LINE_AA)\n        for item in frame_tracks.get(frame_id, []):\n            decision = decision_by_track.get(item["track_id"])\n            if decision is None:\n                continue\n            x, y, w, h = item["bbox"]\n            x1, y1 = int(x), int(y)\n            x2, y2 = int(x + w), int(y + h)\n            label = decision["assigned_identity"]\n            color = color_for_label(label)\n            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)\n            text = f"{label} count={decision[\'display_count\']} score={decision[\'best_score\']:.3f}"\n            draw_label(frame, x1, max(0, y1 - 4), text, color)\n        if (out_width, out_height) != (width, height):\n            frame = cv2.resize(frame, (out_width, out_height), interpolation=cv2.INTER_AREA)\n        writer.write(frame)\n        written_frames += 1\n        frame_id += 1\n\n    cap.release()\n    writer.release()\n    if written_frames == 0:\n        raise RuntimeError("Annotated video rendering produced zero frames.")\n\n\ndef make_browser_playable_video(input_video: Path, output_video: Path) -> Path:\n    """Convert OpenCV MP4 output to browser-friendly H.264 if ffmpeg is available."""\n    try:\n        import imageio_ffmpeg\n\n        ffmpeg = imageio_ffmpeg.get_ffmpeg_exe()\n    except Exception:\n        ffmpeg = shutil.which("ffmpeg")\n\n    if not ffmpeg:\n        return input_video\n\n    output_video.parent.mkdir(parents=True, exist_ok=True)\n    cmd = [\n        ffmpeg,\n        "-y",\n        "-i",\n        str(input_video),\n        "-vcodec",\n        "libx264",\n        "-pix_fmt",\n        "yuv420p",\n        "-movflags",\n        "+faststart",\n        "-an",\n        str(output_video),\n    ]\n    proc = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)\n    if proc.returncode != 0 or not output_video.exists() or output_video.stat().st_size == 0:\n        return input_video\n    return output_video\n\n\ndef build_gallery(model, gallery_files: List[str], run_root: Path, min_frames: int, progress=None):\n    gallery = []\n    metadata = []\n    total = max(len(gallery_files), 1)\n    for idx, gallery_file in enumerate(gallery_files, start=1):\n        label = f"person{idx}"\n        if progress is not None:\n            progress(\n                0.10 + 0.45 * ((idx - 1) / total),\n                desc=f"Building gallery embedding for {label}",\n            )\n        copied_path = copy_upload(\n            gallery_file,\n            run_root / "inputs" / "gallery" / f"{label}{Path(gallery_file).suffix or \'.mp4\'}",\n        )\n        log(f"[gradio] building gallery for {label}: {copied_path}")\n        entries = analyze_video(\n            model=model,\n            video_path=copied_path,\n            work_root=run_root / "work" / "gallery" / label,\n            min_frames=min_frames,\n        )\n        ok_entries = [entry for entry in entries if entry["status"] == "ok"]\n        if not ok_entries:\n            raise gr.Error(f"No valid walking sequence found in gallery video for {label}.")\n        embeddings = np.stack([entry["embedding"].astype(np.float32) for entry in ok_entries], axis=0)\n        prototype = embeddings.mean(axis=0)\n        gallery.append(\n            {\n                "label": label,\n                "source_file": str(copied_path),\n                "embedding": prototype,\n                "valid_entries": len(ok_entries),\n            }\n        )\n        metadata.append(\n            {\n                "label": label,\n                "source_file": str(copied_path),\n                "valid_entries": len(ok_entries),\n                "entry_keys": [entry["entry_key"] for entry in ok_entries],\n                "frame_counts": [entry["frame_count"] for entry in ok_entries],\n            }\n        )\n        if progress is not None:\n            progress(\n                0.10 + 0.45 * (idx / total),\n                desc=f"Finished gallery embedding for {label}",\n            )\n    return gallery, metadata\n\n\ndef score_probe_to_gallery(embedding: np.ndarray, gallery: List[Dict]) -> List[Dict]:\n    scores = []\n    for item in gallery:\n        scores.append(\n            {\n                "label": item["label"],\n                "score": cosine_similarity(embedding, item["embedding"]),\n            }\n        )\n    return sorted(scores, key=lambda item: item["score"], reverse=True)\n\n\ndef assign_probe_entries(\n    probe_entries: List[Dict],\n    gallery: List[Dict],\n    threshold: float,\n) -> List[Dict]:\n    decisions = []\n    counts = Counter()\n    closed_set = len(gallery) >= 2\n\n    for entry in sorted(probe_entries, key=lambda item: item["track_id"]):\n        if entry["status"] != "ok":\n            decisions.append(\n                {\n                    "entry_key": entry["entry_key"],\n                    "video": entry["video"],\n                    "track_id": entry["track_id"],\n                    "frame_count": entry["frame_count"],\n                    "status": entry["status"],\n                    "assigned_identity": "skipped",\n                }\n            )\n            continue\n\n        scores = score_probe_to_gallery(entry["embedding"], gallery)\n        best = scores[0]\n        second = scores[1] if len(scores) > 1 else {"label": "none", "score": -1.0}\n\n        if closed_set:\n            assigned = best["label"]\n        else:\n            assigned = best["label"] if best["score"] >= threshold else "unknown"\n\n        counts[assigned] += 1\n        decisions.append(\n            {\n                "entry_key": entry["entry_key"],\n                "video": entry["video"],\n                "track_id": entry["track_id"],\n                "frame_count": entry["frame_count"],\n                "status": "ok",\n                "assigned_identity": assigned,\n                "display_count": counts[assigned],\n                "best_score": float(best["score"]),\n                "best_identity": best["label"],\n                "second_identity": second["label"],\n                "second_score": float(second["score"]),\n                "all_scores": {item["label"]: float(item["score"]) for item in scores},\n            }\n        )\n    return decisions\n\n\ndef format_ui_summary(ui_summary: Dict) -> str:\n    lines = []\n    mode_label = (\n        "Closed-set gallery matching"\n        if ui_summary["mode"] == "closed_set_best_match"\n        else "Single-gallery threshold fallback"\n    )\n    lines.append("Gait Recognition Result")\n    lines.append("=" * 24)\n    lines.append(f"Mode: {mode_label}")\n    lines.append(f"Model: {ui_summary[\'model\']}")\n    lines.append("")\n    lines.append("Gallery Mapping")\n    for label, filename in ui_summary["gallery_mapping"].items():\n        lines.append(f"- {label}: {filename}")\n    lines.append("")\n    lines.append("Entry Counts")\n    for label, count in sorted(ui_summary["counts"].items()):\n        lines.append(f"- {label}: {count}")\n    lines.append("")\n    lines.append("Processing Summary")\n    lines.append(f"- Processed entries: {ui_summary[\'processed_entries\']}")\n    lines.append(f"- Skipped entries: {ui_summary[\'skipped_entries\']}")\n    lines.append("")\n    lines.append("Output")\n    lines.append(f"- Run folder: {ui_summary[\'run_root\']}")\n    return "\\n".join(lines)\n\n\ndef run_multi_gallery(gallery_files, probe_video, model_name, threshold, min_frames, max_probe_seconds, progress=gr.Progress()):\n    if not gallery_files:\n        raise gr.Error("Please upload at least one gallery video.")\n    if probe_video is None:\n        raise gr.Error("Please upload one probe video.")\n\n    run_root = timestamped_run_root()\n    progress(0.02, desc="Loading selected gait model")\n    model, profile = build_model(model_name)\n\n    progress(0.08, desc="Preparing gallery videos")\n    gallery, gallery_metadata = build_gallery(\n        model=model,\n        gallery_files=gallery_files,\n        run_root=run_root,\n        min_frames=min_frames,\n        progress=progress,\n    )\n\n    progress(0.58, desc="Copying probe video")\n    probe_path = copy_upload(\n        probe_video,\n        run_root / "inputs" / "probe" / f"probe{Path(probe_video).suffix or \'.mp4\'}",\n    )\n    if max_probe_seconds and max_probe_seconds > 0:\n        progress(0.60, desc=f"Clipping probe to first {max_probe_seconds:.1f} seconds")\n        probe_path = clip_video(\n            probe_path,\n            run_root / "inputs" / "probe" / f"probe_first_{int(max_probe_seconds)}s.mp4",\n            float(max_probe_seconds),\n        )\n\n    log(f"[gradio] analyzing probe: {probe_path}")\n    progress(0.62, desc="Tracking, segmenting, and extracting probe embeddings")\n    probe_entries = analyze_video(\n        model=model,\n        video_path=probe_path,\n        work_root=run_root / "work" / "probe",\n        min_frames=min_frames,\n    )\n    progress(0.82, desc="Matching probe entries against gallery")\n    decisions = assign_probe_entries(probe_entries, gallery, threshold=threshold)\n    counts = Counter(\n        decision["assigned_identity"]\n        for decision in decisions\n        if decision["status"] == "ok"\n    )\n\n    tracking_txt = run_root / "work" / "probe" / "tracking" / probe_path.stem / f"{probe_path.stem}.txt"\n    annotated_video_raw = run_root / "annotated_probe_display_raw.mp4"\n    annotated_video = run_root / "annotated_probe_display.mp4"\n    mode = "closed_set_best_match" if len(gallery) >= 2 else "target_vs_unknown_threshold"\n    title = "Gait recognition: closed set" if len(gallery) >= 2 else f"Gait recognition: threshold={threshold:.3f}"\n    progress(0.90, desc="Rendering annotated output video")\n    render_annotations(probe_path, tracking_txt, decisions, annotated_video_raw, title)\n    progress(0.96, desc="Converting annotated video for browser playback")\n    annotated_video = make_browser_playable_video(annotated_video_raw, annotated_video)\n\n    result = {\n        "config": {\n            "mode": mode,\n            "model": profile["display_name"],\n            "model_key": model_name,\n            "threshold_if_single_gallery": threshold,\n            "min_frames": min_frames,\n            "max_probe_seconds": max_probe_seconds,\n            "run_root": str(run_root),\n            "probe_video": str(probe_path),\n        },\n        "gallery": gallery_metadata,\n        "summary": {\n            "gallery_identity_count": len(gallery),\n            "processed_entries": sum(1 for decision in decisions if decision["status"] == "ok"),\n            "skipped_entries": sum(1 for decision in decisions if decision["status"] != "ok"),\n            "counts": dict(counts),\n        },\n        "entries": decisions,\n    }\n\n    result_json = run_root / "result.json"\n    summary_txt = run_root / "summary.txt"\n    result_json.write_text(json.dumps(result, indent=2))\n    summary_txt.write_text(\n        "\\n".join(\n            [\n                "Generic multi-gallery gait recognition summary",\n                f"Mode: {mode}",\n                f"Model: {profile[\'display_name\']}",\n                f"Counts: {dict(counts)}",\n                f"Processed entries: {result[\'summary\'][\'processed_entries\']}",\n                f"Skipped entries: {result[\'summary\'][\'skipped_entries\']}",\n                f"Run folder: {run_root}",\n                f"Annotated video: {annotated_video}",\n            ]\n        )\n    )\n\n    ui_summary = {\n        "mode": mode,\n        "model": model_name,\n        "counts": dict(counts),\n        "processed_entries": result["summary"]["processed_entries"],\n        "skipped_entries": result["summary"]["skipped_entries"],\n        "gallery_mapping": {\n            item["label"]: Path(item["source_file"]).name\n            for item in gallery_metadata\n        },\n        "run_root": str(run_root),\n        "probe_duration_limit_seconds": max_probe_seconds,\n    }\n    progress(1.0, desc="Done")\n    return format_ui_summary(ui_summary), str(annotated_video), str(result_json), str(summary_txt)\n\n\nwith gr.Blocks(title="OpenGait Gallery/Probe Recognition") as demo:\n    gr.Markdown(\n        """\n        # OpenGait Gallery/Probe Recognition\n\n        Upload **any number of gallery videos** and one probe video.\n\n        The app automatically labels gallery videos by upload order:\n        `person1`, `person2`, `person3`, ...\n\n        - If you upload **2 or more gallery videos**, the app runs closed-set recognition: every probe entry is assigned to the most similar gallery person.\n        - If you upload **1 gallery video**, the app falls back to target-vs-unknown thresholding using `person1` vs `unknown`.\n\n        The output includes counts and an annotated overlay video.\n        """\n    )\n\n    with gr.Row():\n        model = gr.Dropdown(\n            choices=["grew_gaitbase", "grew_gaitgl", "current_gaitbase"],\n            value="grew_gaitbase",\n            label="Model",\n        )\n        threshold = gr.Slider(\n            0.90,\n            0.995,\n            value=0.97,\n            step=0.001,\n            label="Threshold, used only when one gallery video is uploaded",\n        )\n        min_frames = gr.Slider(\n            5,\n            80,\n            value=20,\n            step=1,\n            label="Minimum valid silhouette frames per entry",\n        )\n        max_probe_seconds = gr.Slider(\n            0,\n            180,\n            value=0,\n            step=1,\n            label="Max probe duration in seconds, 0 means full video",\n        )\n\n    gallery_files = gr.File(\n        label="Gallery videos, upload one or more",\n        file_count="multiple",\n        file_types=["video"],\n    )\n    probe_file = gr.File(label="Probe video", file_types=["video"])\n    run_button = gr.Button("Run Recognition", variant="primary")\n\n    summary = gr.Textbox(label="Counts and run summary", lines=18)\n    annotated = gr.Video(label="Annotated output video", format="mp4", height=420, width=520, interactive=False)\n    result_file = gr.File(label="Download result JSON")\n    summary_file = gr.File(label="Download summary TXT")\n\n    run_button.click(\n        run_multi_gallery,\n        inputs=[gallery_files, probe_file, model, threshold, min_frames, max_probe_seconds],\n        outputs=[summary, annotated, result_file, summary_file],\n    )\n\n\nif __name__ == "__main__":\n    demo.queue(max_size=1).launch(share=True)\n')
print('Wrote Gradio app to:', app_path)

# %%
# %cd /content/All-in-One-Gait
# !python clean_demo_v2/gradio_app.py
